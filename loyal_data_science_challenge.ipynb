# %% [markdown]
# # Loyal Health Data Science Coding Challenge
#
# Instructions: The following questions are designed to assess your understanding of common data science concepts with which you should be familiar. We’ll have you complete some basic analysis over text reviews and their metadata from the popular music review site Pitchfork (https://pitchfork.com/). The data can be downloaded here (https://www.kaggle.com/nolanbconaway/pitchfork-data) in the form of a SQLite database.  We expect this to take around 2 hours (at most 3 hours) to complete. Although the completion of the assignment will not be strictly timed, please do not go over the allotted time. If time is an issue, focus the most on problems 2, 4, and 5.
#
# Write all of your code in this Jupyter notebook. When you’ve completed the assessment, please create a GitHub repository, and email us a link to this repository.

# %%
# Import here
import sqlite3
import re
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

from scipy.stats import spearmanr
from textblob import TextBlob

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("database.sqlite")

cur = con.cursor()

# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT * FROM genres;'):
    print(row)

# Be sure to close the connection
con.close()
# Out:
# (22703, 'electronic')
# (22721, 'metal')
# (22659, 'rock')
# (22661, 'rock')
# (22725, 'electronic')
# (22722, None)
# (22704, 'rap')
# (22694, 'electronic')
# (22714, 'experimental')
# (22724, 'rap')
# (22715, 'experimental')
# (22745, 'rap')
# (22700, 'electronic')
# (22720, 'rap')
# (22699, 'rap')
# (22665, None)
# (22666, 'experimental')
# (22719, 'rap')
# (22719, 'pop/r&b')
# (22667, 'experimental')
# (22691, 'rap')
# (22691, 'pop/r&b')
# (22702, 'metal')
# (22718, 'rock')
# (22706, 'experimental')
# (22695, 'rock')
# (22695, 'experimental')
# (22713, 'electronic')
# (22705, 'folk/country')
# (22532, 'rock')
# (22701, 'electronic')
# (22707, 'jazz')
# (22708, 'rap')
# (22559, 'metal')
# (22692, 'rap')
# (22677, 'experimental')
# (22469, 'rock')
# (22469, 'rap')
# (22711, 'rap')
# (22678, 'rap')
# (22664, 'jazz')
# (22685, 'rap')
# (22685, 'electronic')
# (22690, None)
# (22689, 'rap')
# (22697, None)
# (22681, 'electronic')
# (22698, 'pop/r&b')
# (22684, 'experimental')
# (22693, 'experimental')
# (22686, 'rap')
# (22643, 'rock')
# (22640, 'electronic')
# (22688, 'electronic')
# (22696, 'rap')
# (22663, 'rock')
# (22687, 'electronic')
# (22662, 'global')
# (22317, 'rock')
# (22673, None)
# (22655, 'rap')
# (22593, None)
# (22627, 'rock')
# (22627, 'electronic')
# (22555, 'electronic')
# (22682, 'rap')
# (22679, 'global')
# (22657, 'electronic')
# (22654, 'rock')
# (22631, 'rock')
# (22683, 'electronic')
# (22635, 'experimental')
# (22653, 'rock')
# (22672, 'rap')
# (22536, 'electronic')
# (22676, 'pop/r&b')
# (22671, 'rap')
# (22675, 'rap')
# (22680, 'folk/country')
# (22641, 'pop/r&b')
# (22645, 'pop/r&b')
# (22393, 'rock')
# (22393, 'experimental')
# (22660, 'jazz')
# (22660, 'electronic')
# (22553, 'rock')
# (22553, 'pop/r&b')
# (22626, 'rock')
# (22639, 'jazz')
# (22658, 'rock')
# (22638, 'experimental')
# (22656, 'electronic')
# (22669, 'rock')
# (22634, 'pop/r&b')
# (22632, 'electronic')
# (22652, 'jazz')
# (22674, 'experimental')
# (22674, 'electronic')
# (22670, 'rap')
# (22646, 'rock')
# (22535, 'electronic')
# (22668, 'pop/r&b')
# (22650, None)
# (22651, 'electronic')
# (22596, 'experimental')
# (22644, 'electronic')
# (22649, 'electronic')
# (22583, 'electronic')
# (22595, 'pop/r&b')
# (22467, 'pop/r&b')
# (22613, 'rap')
# (22620, 'experimental')
# (22633, 'pop/r&b')
# (22597, 'electronic')
# (22561, 'rap')
# (22648, 'pop/r&b')
# (22531, 'rock')
# (22531, 'experimental')
# (22533, 'electronic')
# (22637, 'experimental')
# (22647, 'rap')
# (22614, 'rock')
# (22622, 'rock')
# (22636, 'rock')
# (22629, 'metal')
# (22534, 'electronic')
# (22565, 'rock')
# (22395, 'folk/country')
# (22592, 'electronic')
# (22598, 'rock')
# (22628, 'rock')
# (22624, 'rock')
# (22619, 'rock')
# (22619, 'experimental')
# (22642, 'rock')
# (22603, 'pop/r&b')
# (22594, None)
# (22630, 'rock')
# (22552, 'electronic')
# (22625, 'rock')
# (22618, 'electronic')
# (22602, 'rock')
# (22621, 'rap')
# (22607, 'rap')
# (22611, 'pop/r&b')
# (22616, 'electronic')
# (22617, 'metal')
# (22401, 'folk/country')
# (22394, 'experimental')
# (22457, 'electronic')
# (22501, 'experimental')
# (22612, 'rap')
# (22525, 'folk/country')
# (22610, 'pop/r&b')
# (22518, 'experimental')
# (22527, 'experimental')
# (22623, 'pop/r&b')
# (22563, 'rock')
# (22563, 'global')
# (22563, 'electronic')
# (22505, 'folk/country')
# (22465, 'rock')
# (22465, 'jazz')
# (22465, 'experimental')
# (22465, 'electronic')
# (22506, 'rock')
# (22581, None)
# (22519, 'rock')
# (22608, 'experimental')
# (22573, 'rock')
# (22609, 'electronic')
# (22605, 'rap')
# (22606, 'rock')
# (22502, 'metal')
# (22582, 'pop/r&b')
# (22604, 'rap')
# (22585, 'rap')
# (22560, 'rock')
# (22589, 'electronic')
# (22584, None)
# (22392, 'rock')
# (22347, 'jazz')
# (22571, 'pop/r&b')
# (22586, 'rap')
# (22587, 'folk/country')
# (22550, 'pop/r&b')
# (22464, 'pop/r&b')
# (22570, 'rock')
# (22599, 'rap')
# (22558, 'rock')
# (22415, 'rock')
# (22600, 'pop/r&b')
# (22566, 'rap')
# (22520, 'jazz')
# (22520, 'experimental')
# (22574, 'rap')
# (22452, 'rock')
# (22588, 'rap')
# (22455, 'electronic')
# (22480, 'rap')
# (22543, 'electronic')
# (22579, 'rock')
# (22576, 'experimental')
# (22569, 'pop/r&b')
# (22556, 'pop/r&b')
# (22575, 'rap')
# (22554, 'jazz')
# (22528, 'electronic')
# (22540, 'metal')
# (22374, 'rock')
# (22562, 'rock')
# (22578, 'pop/r&b')
# (22414, 'electronic')
# (22498, 'rock')
# (22413, 'electronic')
# (22572, 'rap')
# (22462, 'electronic')
# (22557, 'metal')
# (22485, 'rock')
# (22547, 'rap')
# (22537, 'rock')
# (22441, 'rock')
# (22517, 'electronic')
# (22523, 'rap')
# (22551, 'pop/r&b')
# (22568, 'electronic')
# (22483, 'jazz')
# (22567, None)
# (22549, 'rock')
# (22545, 'pop/r&b')
# (22546, 'electronic')
# (22526, 'rock')
# (22529, 'rock')
# (22500, 'electronic')
# (22548, 'electronic')
# (22524, 'pop/r&b')
# (22324, 'rock')
# (22442, 'experimental')
# (22442, 'electronic')
# (22516, 'jazz')
# (22514, 'rock')
# (22542, None)
# (22454, 'rock')
# (22436, None)
# (22377, 'rock')
# (22291, 'rock')
# (22378, 'rock')
# (22541, None)
# (22503, 'metal')
# (22479, 'rock')
# (22522, 'rap')
# (22515, 'electronic')
# (22530, 'electronic')
# (22507, 'rap')
# (22521, 'rock')
# (22512, 'electronic')
# (22508, 'rock')
# (22509, 'folk/country')
# (22463, 'rock')
# (22513, 'rap')
# (22412, 'electronic')
# (22504, None)
# (22389, 'pop/r&b')
# (22499, 'rock')
# (22495, 'metal')
# (22461, 'global')
# (22494, 'pop/r&b')
# (22440, 'folk/country')
# (22496, 'rock')
# (22497, 'jazz')
# (22458, 'rock')
# (22308, 'rock')
# (22390, 'electronic')
# (22511, 'rap')
# (22493, 'electronic')
# (22339, 'rock')
# (22490, 'electronic')
# (22404, 'rock')
# (22372, 'global')
# (22411, 'electronic')
# (22348, 'rock')
# (22391, 'rap')
# (22410, 'electronic')
# (22492, 'rock')
# (22488, 'rock')
# (22477, 'rock')
# (22489, 'pop/r&b')
# (22438, 'electronic')
# (22323, 'folk/country')
# (22307, 'jazz')
# (22307, 'pop/r&b')
# (22486, 'rap')
# (22478, 'global')
# (22478, 'rap')
# (22474, 'rock')
# (22450, 'experimental')
# (22449, 'folk/country')
# (22460, 'metal')
# (22439, 'metal')
# (22253, 'pop/r&b')
# (22318, 'rock')
# (22445, 'electronic')
# (22484, 'rap')
# (22466, 'metal')
# (22429, 'pop/r&b')
# (22451, 'rock')
# (22471, 'pop/r&b')
# (22470, 'electronic')
# (22437, 'rock')
# (22475, 'pop/r&b')
# (22476, 'metal')
# (22472, 'experimental')
# (22482, 'pop/r&b')
# (22376, 'rock')
# (22459, 'experimental')
# (22375, 'electronic')
# (22314, 'experimental')
# (22362, 'folk/country')
# (22435, 'global')
# (22373, 'metal')
# (22447, 'pop/r&b')
# (22468, 'rap')
# (22446, 'rap')
# (22299, 'jazz')
# (22434, 'experimental')
# (22292, 'rock')
# (22368, 'rock')
# (22430, 'electronic')
# (22346, 'experimental')
# (22388, 'electronic')
# (22420, 'rock')
# (22298, 'electronic')
# (22304, 'electronic')
# (22425, 'experimental')
# (22444, 'electronic')
# (22426, 'rock')
# (22424, 'experimental')
# (22315, 'rock')
# (22431, 'rap')
# (22443, 'rap')
# (22432, 'rock')
# (22427, 'rock')
# (22423, 'folk/country')
# (22387, 'electronic')
# (22146, 'rap')
# (22386, 'folk/country')
# (22416, 'pop/r&b')
# (22416, 'electronic')
# (22134, 'rock')
# (22422, 'rock')
# (22370, 'rock')
# (22400, 'pop/r&b')
# (22045, 'pop/r&b')
# (22419, 'rock')
# (22428, 'rap')
# (22406, 'electronic')
# (22369, 'electronic')
# (22313, 'rock')
# (22313, 'pop/r&b')
# (22405, 'rock')
# (22302, 'experimental')
# (22399, 'rap')
# (22409, 'rock')
# (22421, 'rap')
# (22385, 'rock')
# (22384, 'rap')
# (22418, 'pop/r&b')
# (22326, 'metal')
# (22366, 'rap')
# (22367, 'rock')
# (22402, 'rock')
# (22382, None)
# (22383, 'electronic')
# (22408, 'electronic')
# (22407, 'rock')
# (22312, 'jazz')
# (22381, 'electronic')
# (22357, 'metal')
# (22061, 'experimental')
# (22293, 'rap')
# (22310, 'experimental')
# (22398, 'rock')
# (22398, 'experimental')
# (22403, 'rap')
# (22397, 'rock')
# (22359, 'rock')
# (22365, 'electronic')
# (22358, 'jazz')
# (22358, 'experimental')
# (22300, 'experimental')
# (22335, 'rap')
# (22379, 'metal')
# (22360, 'rock')
# (22336, 'rock')
# (22283, None)
# (22303, 'electronic')
# (22306, 'rock')
# (22396, 'global')
# (22396, 'pop/r&b')
# (22343, 'rock')
# (22305, 'experimental')
# (22238, None)
# (22350, 'rock')
# (22356, 'experimental')
# (22112, 'electronic')
# (22309, 'folk/country')
# (22345, 'experimental')
# (22255, 'global')
# (22327, 'experimental')
# (22288, 'rock')
# (22364, 'rap')
# (22380, 'folk/country')
# (22355, 'rock')
# (22289, 'rock')
# (22290, 'electronic')
# (22330, 'folk/country')
# (22330, 'electronic')
# (22361, 'rap')
# (22284, 'rock')
# (22354, 'pop/r&b')
# (22351, 'pop/r&b')
# (22363, 'rap')
# (22281, 'electronic')
# (22342, 'jazz')
# (22352, 'electronic')
# (22322, 'electronic')
# (22287, 'rock')
# (22344, 'rap')
# (22286, None)
# (22212, 'experimental')
# (22353, 'rap')
# (22349, 'rock')
# (22337, None)
# (21989, 'rock')
# (22282, 'rock')
# (22332, 'rock')
# (22332, 'electronic')
# (22333, 'experimental')
# (22277, 'experimental')
# (22329, 'rap')
# (22338, 'rock')
# (22338, 'pop/r&b')
# (22341, 'rock')
# (22341, 'experimental')
# (22341, 'electronic')
# (22271, 'jazz')
# (22319, 'rock')
# (22319, 'rap')
# (22331, 'rock')
# (22325, 'electronic')
# (22320, 'rock')
# (22320, 'experimental')
# (22296, 'rap')
# (22243, 'electronic')
# (22328, 'rock')
# (22279, 'folk/country')
# (22256, 'rock')
# (22340, 'rap')
# (22251, 'rock')
# (22257, 'electronic')
# (22132, 'rap')
# (22254, 'rock')
# (22252, 'electronic')
# (22260, 'experimental')
# (22321, 'electronic')
# (22280, 'rap')
# (22231, 'electronic')
# (22311, 'folk/country')
# (22295, 'pop/r&b')
# (22285, None)
# (22249, 'experimental')
# (22258, 'experimental')
# (22211, 'rap')
# (22223, 'rock')
# (22276, None)
# (22237, 'electronic')
# (22273, 'pop/r&b')
# (22274, 'rap')
# (22241, 'rock')
# (22233, 'experimental')
# (22248, 'rock')
# (22236, 'electronic')
# (22242, 'rock')
# (22239, 'global')
# (22239, 'jazz')
# (22239, 'rap')
# (22174, 'pop/r&b')
# (22267, 'rap')
# (22270, 'rock')
# (22270, 'experimental')
# (22230, 'experimental')
# (22169, 'rock')
# (22246, 'electronic')
# (22272, 'rock')
# (22227, None)
# (22228, 'rock')
# (22245, 'rock')
# (22210, 'rap')
# (22264, 'rock')
# (22263, 'rock')
# (22265, 'electronic')
# (22261, 'rap')
# (22234, 'electronic')
# (22226, 'rock')
# (22262, None)
# (22193, 'pop/r&b')
# (22244, 'rock')
# (22217, 'rock')
# (22232, 'rap')
# (22020, 'rap')
# (22215, 'rock')
# (22225, 'electronic')
# (22220, None)
# (22131, 'rock')
# (22221, 'rap')
# (22247, 'rock')
# (22198, 'folk/country')
# (22214, 'electronic')
# (22185, 'rock')
# (22207, 'electronic')
# (22189, 'electronic')
# (22240, 'rap')
# (22150, 'rock')
# (22197, 'electronic')
# (22213, 'rock')
# (22208, 'electronic')
# (22202, None)
# (22219, None)
# (22206, 'pop/r&b')
# (22151, 'electronic')
# (22137, None)
# (22200, None)
# (22216, 'electronic')
# (22209, 'electronic')
# (22170, 'pop/r&b')
# (22170, 'electronic')
# (22139, 'rock')
# (22218, 'rap')
# (22182, 'electronic')
# (22203, 'experimental')
# (22044, 'pop/r&b')
# (22186, 'rock')
# (22204, 'rap')
# (22188, 'jazz')
# (22188, 'experimental')
# (22205, 'metal')
# (22191, 'rap')
# (22191, 'pop/r&b')
# (22199, 'rap')
# (22195, 'electronic')
# (22148, 'electronic')
# (22196, 'rock')
# (22196, 'metal')
# (22201, 'rap')
# (22187, 'folk/country')
# (22179, 'rock')
# (22149, 'rock')
# (22152, None)
# (22192, 'electronic')
# (22165, None)
# (22163, 'pop/r&b')
# (22143, 'electronic')
# (22183, 'electronic')
# (22178, 'rock')
# (22168, 'rock')
# (22145, 'experimental')
# (22142, 'metal')
# (22184, 'electronic')
# (22162, 'experimental')
# (22107, 'rock')
# (22159, 'jazz')
# (22159, 'pop/r&b')
# (22118, None)
# (22194, 'rock')
# (22133, 'metal')
# (22173, 'global')
# (22113, 'experimental')
# (22190, 'electronic')
# (22172, 'global')
# (22180, 'pop/r&b')
# (22136, 'rap')
# (22181, 'folk/country')
# (22130, 'electronic')
# (22177, 'rap')
# (22147, 'rock')
# (22147, 'metal')
# (22175, 'electronic')
# (22129, 'metal')
# (22157, 'rap')
# (22128, None)
# (22160, 'rap')
# (22098, 'rock')
# (22098, 'metal')
# (22167, 'rap')
# (22171, 'rap')
# (21886, 'pop/r&b')
# (22154, 'rock')
# (22166, None)
# (22043, 'rap')
# (22161, 'rap')
# (22123, 'rock')
# (22144, 'rock')
# (22176, 'pop/r&b')
# (22119, 'electronic')
# (22121, 'rap')
# (22126, None)
# (22158, 'rock')
# (22158, 'experimental')
# (22158, 'electronic')
# (22156, 'pop/r&b')
# (22135, 'rap')
# (22106, 'global')
# (22140, 'rock')
# (22120, 'experimental')
# (22110, 'pop/r&b')
# (22138, 'rap')
# (22127, 'metal')
# (22109, 'jazz')
# (22117, 'electronic')
# (22125, 'rock')
# (22125, 'electronic')
# (22155, 'experimental')
# (22101, 'rap')
# (22103, 'experimental')
# (22116, 'rock')
# (22124, 'electronic')
# (22087, 'electronic')
# (21924, 'rock')
# (22073, 'rock')
# (22141, 'rap')
# (22062, 'electronic')
# (22108, None)
# (22075, 'pop/r&b')
# (22111, 'rock')
# (22122, 'experimental')
# (22105, 'electronic')
# (22094, 'rap')
# (22090, 'electronic')
# (22064, None)
# (22102, 'experimental')
# (22093, 'experimental')
# (22100, 'electronic')
# (22095, 'rock')
# (22114, 'electronic')
# (22057, 'pop/r&b')
# (22097, 'experimental')
# (22088, 'experimental')
# (22099, 'metal')
# (21895, 'rock')
# (21895, 'global')
# (22085, 'pop/r&b')
# (22071, 'electronic')
# (22059, 'rock')
# (22104, 'pop/r&b')
# (22035, 'pop/r&b')
# (22060, 'pop/r&b')
# (22092, 'folk/country')
# (22016, 'folk/country')
# (22026, 'electronic')
# (22065, 'electronic')
# (22091, 'electronic')
# (22086, 'pop/r&b')
# (22086, 'experimental')
# (22015, 'jazz')
# (22015, 'metal')
# (22072, 'electronic')
# (22074, 'metal')
# (22089, 'rap')
# (22027, 'rock')
# (22027, 'electronic')
# (22080, 'rock')
# (22083, 'pop/r&b')
# (21883, 'pop/r&b')
# (22076, 'experimental')
# (22067, 'rock')
# (22084, 'rock')
# (22069, 'rock')
# (22056, 'rock')
# (22054, 'rock')
# (22079, 'rap')
# (22081, 'rock')
# (22063, 'rock')
# (22082, 'experimental')
# (22077, 'rap')
# (22078, 'electronic')
# (22066, None)
# (22022, 'experimental')
# (22052, 'pop/r&b')
# (22070, None)
# (22029, 'pop/r&b')
# (22021, 'rock')
# (22030, 'experimental')
# (22013, 'rock')
# (22013, 'experimental')
# (21969, 'folk/country')
# (22001, None)
# (22055, 'rock')
# (22041, 'rock')
# (22041, 'metal')
# (22068, 'rock')
# (22042, 'electronic')
# (22039, 'electronic')
# (21985, 'rock')
# (22018, 'rock')
# (22018, 'electronic')
# (22058, 'pop/r&b')
# (21968, None)
# (22053, 'rock')
# (22019, 'electronic')
# (22014, 'rock')
# (22014, 'electronic')
# (22038, 'jazz')
# (22038, 'experimental')
# (22007, 'jazz')
# (22050, 'rock')
# (21719, 'pop/r&b')
# (22012, None)
# (22032, 'experimental')
# (22049, 'electronic')
# (22048, 'rock')
# (22017, 'electronic')
# (22005, 'rock')
# (21970, 'rock')
# (22036, 'rap')
# (21971, 'folk/country')
# (21979, 'rock')
# (21994, 'rock')
# (21988, 'rap')
# (21984, 'electronic')
# (22000, 'pop/r&b')
# (21992, 'rock')
# (22010, 'electronic')
# (22011, 'rock')
# (22034, None)
# (21951, 'electronic')
# (22037, 'rock')
# (22024, 'rock')
# (21884, 'rock')
# (22046, 'rap')
# (21982, 'metal')
# (21973, 'rock')
# (21726, 'rock')
# (22033, 'rock')
# (21991, 'electronic')
# (22004, 'rock')
# (22040, 'pop/r&b')
# (21974, 'rock')
# (21974, 'electronic')
# (22008, 'experimental')
# (22006, 'rock')
# (21972, 'electronic')
# (22031, 'rap')
# (21945, 'rock')
# (21995, 'rock')
# (21965, 'rock')
# (21965, 'electronic')
# (21882, 'experimental')
# (22002, 'jazz')
# (21990, 'electronic')
# (21885, 'experimental')
# (21967, 'electronic')
# (21966, 'rock')
# (21966, 'global')
# (21966, 'experimental')
# (21966, 'electronic')
# (21889, 'metal')
# (21964, 'pop/r&b')
# (21980, 'electronic')
# (21946, 'rock')
# (21946, 'pop/r&b')
# (21946, 'electronic')
# (21941, 'rock')
# (21941, 'electronic')
# (21931, 'rock')
# (21953, 'rock')
# (21987, 'rock')
# (21996, 'electronic')
# (21999, 'rock')
# (21998, 'rap')
# (21978, 'rock')
# (21961, 'rock')
# (21961, 'electronic')
# (21722, 'rock')
# (21952, 'rock')
# (21997, None)
# (21872, 'rock')
# (21954, 'rock')
# (21986, 'rock')
# (21962, 'rock')
# (21962, 'electronic')
# (21938, 'electronic')
# (21654, 'metal')
# (21871, 'rock')
# (21828, 'rock')
# (21959, 'rock')
# (21959, 'metal')
# (21977, 'rock')
# (21981, 'rap')
# (21904, 'rap')
# (21873, 'folk/country')
# (21960, 'global')
# (21890, None)
# (21913, 'rap')
# (21932, 'pop/r&b')
# (21942, 'pop/r&b')
# (21937, None)
# (21921, 'electronic')
# (21916, 'folk/country')
# (21976, 'rap')
# (21915, 'rock')
# (21944, 'rock')
# (21723, 'electronic')
# (21958, 'electronic')
# (21975, 'rock')
# (21957, 'rap')
# (21917, 'rock')
# (21943, 'rock')
# (21910, 'rock')
# (21956, 'folk/country')
# (21891, 'pop/r&b')
# (21718, 'rock')
# (21922, 'pop/r&b')
# (21786, 'electronic')
# (21950, 'electronic')
# (21821, 'jazz')
# (21947, 'electronic')
# (21934, 'experimental')
# (21675, 'rock')
# (21940, 'rap')
# (21933, 'folk/country')
# (21949, 'global')
# (21948, 'rock')
# (21955, 'rock')
# (21536, None)
# (21936, 'rock')
# (21892, 'pop/r&b')
# (21874, 'electronic')
# (21584, 'experimental')
# (21880, 'rock')
# (21896, 'rock')
# (21923, 'pop/r&b')
# (21929, 'rock')
# (21914, 'folk/country')
# (21939, 'rock')
# (21926, 'electronic')
# (21893, 'experimental')
# (21868, 'rock')
# (21920, 'electronic')
# (21864, 'folk/country')
# (21894, 'rock')
# (21935, 'rock')
# (21721, 'jazz')
# (21673, 'rock')
# (21928, 'rap')
# (21898, 'rock')
# (21875, 'rock')
# (21875, 'folk/country')
# (21771, None)
# (21725, 'folk/country')
# (21912, 'electronic')
# (21865, 'pop/r&b')
# (21802, 'pop/r&b')
# (21676, 'rock')
# (21887, 'rock')
# (21919, 'electronic')
# (21909, 'rap')
# (21700, 'rock')
# (21911, 'electronic')
# (21869, 'rock')
# (21918, 'jazz')
# (21677, 'rock')
# (21818, 'metal')
# (21784, 'rock')
# (21862, 'rock')
# (21901, 'rock')
# (21858, 'rap')
# (21900, 'pop/r&b')
# (21877, 'rock')
# (21899, 'pop/r&b')
# (21785, 'electronic')
# (21724, 'rock')
# (21908, 'global')
# (21879, 'rap')
# (21879, 'experimental')
# (21876, 'electronic')
# (21820, 'electronic')
# (21859, 'rock')
# (21907, 'rock')
# (21888, 'rock')
# (21678, 'jazz')
# (21878, 'folk/country')
# (21906, 'pop/r&b')
# (21861, 'folk/country')
# (21863, 'rap')
# (21852, 'rock')
# (21782, 'electronic')
# (21783, 'electronic')
# (21855, 'rap')
# (21720, 'rock')
# (21817, 'jazz')
# (21701, 'rock')
# (21701, 'global')
# (21701, 'experimental')
# (21701, 'electronic')
# (21854, None)
# (21856, 'rock')
# (21905, 'rock')
# (21849, 'rock')
# (21860, None)
# (21645, 'metal')
# (21857, 'pop/r&b')
# (21857, 'electronic')
# (21819, 'pop/r&b')
# (21819, 'experimental')
# (21794, 'rock')
# (21810, None)
# (21815, None)
# (21687, 'rap')
# (21804, 'electronic')
# (21853, None)
# (21851, 'rock')
# (21848, 'rock')
# (21848, 'electronic')
# (21653, None)
# (21813, 'rock')
# (21813, 'electronic')
# (21903, 'rap')
# (21816, 'rock')
# (21836, 'rap')
# (21835, None)
# (21850, 'pop/r&b')
# (21801, 'experimental')
# (21845, 'rock')
# (21845, 'pop/r&b')
# (21842, 'rock')
# (21842, 'pop/r&b')
# (21844, 'rock')
# (21844, 'pop/r&b')
# (21846, 'rock')
# (21846, 'pop/r&b')
# (21841, 'rock')
# (21841, 'pop/r&b')
# (21866, 'rock')
# (21866, 'pop/r&b')
# (21843, 'rock')
# (21843, 'pop/r&b')
# (21847, 'rock')
# (21847, 'pop/r&b')
# (21715, 'rock')
# (21839, 'rap')
# (21637, 'rap')
# (21781, 'experimental')
# (21743, 'experimental')
# (21806, 'rock')
# (21806, 'experimental')
# (21834, 'electronic')
# (21825, 'rap')
# (21867, 'pop/r&b')
# (21826, 'rap')
# (21838, 'rock')
# (21837, 'rap')
# (21833, 'electronic')
# (21797, 'jazz')
# (21762, 'metal')
# (21762, 'experimental')
# (21717, 'rock')
# (21814, 'rock')
# (21814, 'experimental')
# (21694, 'experimental')
# (21799, 'jazz')
# (21840, 'rap')
# (21744, 'rock')
# (21714, 'rock')
# (21696, 'global')
# (21696, 'electronic')
# (21832, 'metal')
# (21827, 'rock')
# (21808, 'rock')
# (21807, 'experimental')
# (21792, 'rock')
# (21695, 'electronic')
# (21709, 'rap')
# (21778, 'electronic')
# (21708, None)
# (21809, None)
# (21758, 'folk/country')
# (21791, 'rock')
# (21699, 'experimental')
# (21831, 'experimental')
# (21831, 'electronic')
# (21822, 'rock')
# (21822, 'experimental')
# (21800, 'rock')
# (21733, 'rock')
# (21729, 'rap')
# (21824, 'rap')
# (21681, 'rock')
# (21680, 'experimental')
# (21829, 'rap')
# (21636, 'folk/country')
# (21703, 'experimental')
# (21698, 'rock')
# (21749, 'rock')
# (21749, 'experimental')
# (21697, 'rock')
# (21742, 'rock')
# (21780, 'electronic')
# (21755, 'metal')
# (21688, 'pop/r&b')
# (21812, 'rap')
# (21716, 'rock')
# (21732, 'metal')
# (21732, 'electronic')
# (21547, 'rock')
# (21547, 'metal')
# (21562, 'experimental')
# (21811, 'rock')
# (21770, 'pop/r&b')
# (21752, 'pop/r&b')
# (21769, 'rock')
# (21769, 'electronic')
# (21690, 'electronic')
# (21679, 'rock')
# (21803, 'pop/r&b')
# (21693, None)
# (21597, 'rock')
# (21748, 'rock')
# (21767, 'pop/r&b')
# (21594, 'rock')
# (21704, 'rock')
# (21635, 'experimental')
# (21796, 'rap')
# (21796, 'experimental')
# (21750, 'rock')
# (21805, 'pop/r&b')
# (21587, 'rock')
# (21775, 'pop/r&b')
# (21766, 'electronic')
# (21751, 'rock')
# (21728, 'rock')
# (21674, 'jazz')
# (21756, 'pop/r&b')
# (21768, 'rock')
# (21768, 'electronic')
# (21596, 'rock')
# (21747, 'rock')
# (21776, 'rock')
# (21628, 'electronic')
# (21627, 'electronic')
# (21576, 'electronic')
# (21633, 'rock')
# (21633, 'metal')
# (21757, 'rock')
# (21757, 'electronic')
# (21765, 'rock')
# (21779, 'rock')
# (21741, 'rap')
# (21626, 'electronic')
# (21777, 'rock')
# (21777, 'pop/r&b')
# (21777, 'folk/country')
# (21790, 'rap')
# (21763, 'pop/r&b')
# (21595, 'rock')
# (21538, None)
# (21537, None)
# (21593, 'rock')
# (21789, 'rap')
# (21551, 'electronic')
# (21660, 'folk/country')
# (21710, 'pop/r&b')
# (21710, 'electronic')
# (21764, 'pop/r&b')
# (21754, 'electronic')
# (21788, 'rap')
# (21629, 'rock')
# (21652, 'electronic')
# (21686, 'rock')
# (21761, 'electronic')
# (21740, 'rap')
# (21535, 'jazz')
# (21535, 'experimental')
# (21746, 'electronic')
# (21656, 'electronic')
# (21685, 'metal')
# (21625, 'electronic')
# (21702, 'electronic')
# (21641, 'experimental')
# (21712, 'rap')
# (21759, 'rock')
# (21664, 'rap')
# (21745, 'folk/country')
# (21737, 'experimental')
# (21518, 'jazz')
# (21683, 'pop/r&b')
# (21738, 'electronic')
# (21773, 'rap')
# (21615, 'pop/r&b')
# (21707, 'rap')
# (21550, 'rock')
# (21730, 'pop/r&b')
# (21684, 'metal')
# (21727, 'rock')
# (21647, 'pop/r&b')
# (21672, 'rock')
# (21672, 'metal')
# (21672, 'experimental')
# (21739, 'rock')
# (21614, None)
# (21617, 'rap')
# (21591, 'folk/country')
# (21591, 'experimental')
# (21646, 'experimental')
# (21646, 'electronic')
# (21692, 'rock')
# (21650, 'rock')
# (21640, 'metal')
# (21590, 'rock')
# (21736, 'rap')
# (21605, 'rock')
# (21670, None)
# (21753, 'experimental')
# (21588, 'rock')
# (21549, 'rap')
# (21666, 'rock')
# (21632, 'experimental')
# (21606, 'electronic')
# (21509, 'electronic')
# (21631, 'metal')
# (21713, 'rap')
# (21630, 'rock')
# (21616, 'experimental')
# (21731, 'rock')
# (21668, 'electronic')
# (21711, 'global')
# (21711, 'electronic')
# (21658, 'rock')
# (21612, 'experimental')
# (21563, 'electronic')
# (21667, 'pop/r&b')
# (21644, 'rock')
# (21642, 'rock')
# (21691, 'rock')
# (21586, 'rock')
# (21555, 'electronic')
# (21669, 'electronic')
# (21546, 'rock')
# (21655, 'rock')
# (21665, 'experimental')
# (21706, 'rap')
# (21443, 'rock')
# (21651, 'rock')
# (21659, 'electronic')
# (21705, 'rap')
# (21526, 'rock')
# (21643, 'rap')
# (21486, 'rock')
# (21623, 'rock')
# (21527, 'experimental')
# (21603, 'electronic')
# (21415, 'rock')
# (21648, 'rock')
# (21624, 'experimental')
# (21575, 'jazz')
# (21682, 'electronic')
# (21569, 'experimental')
# (21534, 'experimental')
# (21613, 'rock')
# (21561, 'folk/country')
# (21574, 'rock')
# (21622, 'folk/country')
# (21512, 'electronic')
# (21610, 'metal')
# (21558, 'rock')
# (21585, 'electronic')
# (21583, 'rock')
# (21582, 'rap')
# (21661, 'electronic')
# (21663, 'rock')
# (21573, 'electronic')
# (21600, 'rock')
# (21600, 'rap')
# (21408, 'rock')
# (21621, 'global')
# (21621, 'electronic')
# (21510, 'rock')
# (21604, 'rap')
# (21567, 'rock')
# (21611, 'electronic')
# (21639, None)
# (21504, 'rap')
# (21609, 'rock')
# (21453, 'rock')
# (21572, 'electronic')
# (21570, 'experimental')
# (21412, 'rock')
# (21544, 'rap')
# (21619, 'rock')
# (21435, 'electronic')
# (21657, 'rap')
# (21548, 'pop/r&b')
# (21607, None)
# (21560, 'rock')
# (21608, 'rap')
# (21620, 'electronic')
# (21439, 'pop/r&b')
# (21602, 'rap')
# (21638, 'rock')
# (21452, 'rock')
# (21559, 'electronic')
# (21601, None)
# (21470, 'rock')
# (21466, 'pop/r&b')
# (21545, 'rock')
# (21571, 'electronic')
# (21339, 'rock')
# (21339, 'folk/country')
# (21339, 'metal')
# (21557, 'pop/r&b')
# (21523, 'rock')
# (21414, 'experimental')
# (21467, 'experimental')
# (21599, 'rock')
# (21017, 'experimental')
# (21568, 'pop/r&b')
# (21495, 'rock')
# (21508, 'rock')
# (21580, 'electronic')
# (21525, 'rock')
# (21566, 'rap')
# (21533, 'electronic')
# (21564, 'rock')
# (21333, 'rock')
# (21333, 'experimental')
# (21398, 'global')
# (21398, 'electronic')
# (21465, 'rock')
# (21556, 'global')
# (21581, 'rap')
# (21542, 'rap')
# (21543, 'folk/country')
# (21494, 'electronic')
# (21419, 'experimental')
# (21524, 'rock')
# (21565, 'rap')
# (21598, 'rap')
# (21492, 'rock')
# (21531, 'rock')
# (21493, 'electronic')
# (21578, 'rap')
# (21522, 'rock')
# (21532, 'rap')
# (21468, 'pop/r&b')
# (21577, 'folk/country')
# (21410, 'rock')
# (21507, 'rock')
# (21554, 'rap')
# (21529, 'metal')
# (21413, None)
# (21579, 'rap')
# (21511, 'rock')
# (21530, 'electronic')
# (21463, 'jazz')
# (21521, 'pop/r&b')
# (21514, 'rock')
# (21520, 'rap')
# (21485, 'rock')
# (21515, 'global')
# (21515, 'folk/country')
# (21516, 'electronic')
# (21553, 'electronic')
# (21409, 'electronic')
# (21482, 'rock')
# (21451, 'rock')
# (21539, 'electronic')
# (21287, 'rap')
# (21513, 'rock')
# (21513, 'electronic')
# (21552, 'electronic')
# (21464, 'electronic')
# (21484, 'rock')
# (21499, None)
# (21502, 'pop/r&b')
# (21541, 'rap')
# (21469, 'pop/r&b')
# (21528, 'rap')
# (21462, 'rock')
# (21506, 'pop/r&b')
# (21483, 'rock')
# (21498, 'metal')
# (21519, 'electronic')
# (21540, 'pop/r&b')
# (21472, 'rock')
# (21517, 'rap')
# (21459, 'pop/r&b')
# (21437, 'electronic')
# (21480, 'rap')
# (21471, 'rock')
# (21450, 'electronic')
# (21382, 'rock')
# (21456, 'metal')
# (21456, 'experimental')
# (21481, 'pop/r&b')
# (21461, 'folk/country')
# (21479, 'rock')
# (21433, 'rock')
# (21489, 'rock')
# (21384, 'rock')
# (21449, 'rock')
# (21335, 'experimental')
# (21383, 'rock')
# (21396, None)
# (21460, 'pop/r&b')
# (21310, 'rock')
# (21407, 'experimental')
# (21381, None)
# (21444, 'rock')
# (21497, 'rock')
# (21441, 'rock')
# (21473, 'folk/country')
# (21445, 'rock')
# (21438, 'rock')
# (21487, 'rock')
# (21476, 'rock')
# (21478, 'rock')
# (21477, 'rock')
# (21488, 'rock')
# (21496, 'rap')
# (21442, 'pop/r&b')
# (21448, 'rap')
# (21457, 'rap')
# (21440, 'rap')
# (21475, 'pop/r&b')
# (21380, 'rock')
# (21417, 'rock')
# (21400, 'rock')
# (21458, 'rock')
# (21434, 'rock')
# (21406, 'rock')
# (21406, 'experimental')
# (21490, 'rap')
# (21436, 'rock')
# (21455, 'folk/country')
# (21428, 'rock')
# (21345, 'jazz')
# (21454, 'rock')
# (21420, 'experimental')
# (21431, 'electronic')
# (21402, 'pop/r&b')
# (21403, 'rap')
# (21422, 'metal')
# (21430, 'pop/r&b')
# (21432, 'metal')
# (21397, 'rap')
# (21423, 'rock')
# (21426, 'rap')
# (21347, 'metal')
# (21429, 'rock')
# (21394, None)
# (21388, 'rock')
# (21421, 'electronic')
# (21395, 'metal')
# (21446, 'rap')
# (21392, 'rap')
# (21391, 'electronic')
# (21418, 'rock')
# (21425, 'rock')
# (21393, 'rock')
# (21387, 'pop/r&b')
# (21399, 'rock')
# (21405, 'electronic')
# (21447, None)
# (21389, 'folk/country')
# (21353, 'rock')
# (21353, 'pop/r&b')
# (21378, 'rap')
# (21386, 'rap')
# (21330, 'rock')
# (21404, 'electronic')
# (21332, 'rock')
# (21355, 'rap')
# (21370, 'pop/r&b')
# (21424, 'rap')
# (21385, 'global')
# (21351, 'rock')
# (21351, 'rap')
# (21377, 'electronic')
# (21416, None)
# (21368, 'rap')
# (21350, 'jazz')
# (21369, 'experimental')
# (21343, 'rock')
# (21341, 'rap')
# (21341, 'pop/r&b')
# (21348, 'electronic')
# (21338, 'rock')
# (21337, 'rap')
# (21328, 'rock')
# (21349, 'rap')
# (21331, 'rock')
# (21352, None)
# (21326, 'rock')
# (21326, 'electronic')
# (21329, 'rap')
# (20947, 'rock')
# (20947, 'electronic')
# (21342, 'rock')
# (21296, None)
# (21179, 'metal')
# (21344, 'rap')
# (21312, 'rap')
# (21308, 'rap')
# (21325, 'rap')
# (21340, 'pop/r&b')
# (21336, 'rock')
# (21324, 'rock')
# (21256, 'experimental')
# (21327, 'electronic')
# (21305, None)
# (21317, 'rock')
# (21309, 'rock')
# (21297, 'folk/country')
# (21313, 'electronic')
# (21306, 'rock')
# (21289, 'rock')
# (21307, 'rock')
# (21283, 'experimental')
# (21280, None)
# (21321, 'rock')
# (21292, 'rap')
# (21265, 'electronic')
# (21318, 'electronic')
# (21322, 'experimental')
# (21286, 'metal')
# (21286, 'experimental')
# (21235, 'rock')
# (21228, 'pop/r&b')
# (21263, 'metal')
# (20996, None)
# (21212, 'electronic')
# (21302, 'electronic')
# (21259, 'rock')
# (21281, 'rap')
# (21293, 'rap')
# (21319, 'pop/r&b')
# (21209, 'rap')
# (21294, 'electronic')
# (21269, 'pop/r&b')
# (21304, 'pop/r&b')
# (21295, 'rock')
# (21315, 'rock')
# (21245, 'rock')
# (21320, 'rap')
# (21288, 'electronic')
# (21158, 'jazz')
# (21301, 'rock')
# (21270, 'experimental')
# (21250, 'folk/country')
# (21208, 'metal')
# (21279, 'rock')
# (21169, 'electronic')
# (21299, 'electronic')
# (21201, 'metal')
# (21134, 'metal')
# (21246, 'pop/r&b')
# (21275, 'rock')
# (21240, 'electronic')
# (21258, 'electronic')
# (21242, 'metal')
# (21164, 'rap')
# (21274, 'rap')
# (21300, 'rock')
# (21237, 'pop/r&b')
# (21233, 'experimental')
# (21213, 'global')
# (21189, 'experimental')
# (21277, 'electronic')
# (21159, 'electronic')
# (21239, 'rap')
# (21231, 'experimental')
# (21221, 'electronic')
# (21216, 'rap')
# (21285, 'pop/r&b')
# (21241, 'experimental')
# (21248, 'pop/r&b')
# (21163, 'pop/r&b')
# (21135, 'experimental')
# (21255, 'rap')
# (21141, 'rock')
# (20916, 'rap')
# (21261, 'rock')
# (21225, 'electronic')
# (21247, 'pop/r&b')
# (20588, None)
# (21218, 'rap')
# (21271, 'pop/r&b')
# (21217, 'experimental')
# (21266, 'rock')
# (21273, 'pop/r&b')
# (21157, 'rock')
# (21109, 'rap')
# (21215, 'rap')
# (21205, 'experimental')
# (21276, 'rock')
# (21253, 'electronic')
# (21254, 'rock')
# (21272, 'rap')
# (21203, None)
# (21252, 'pop/r&b')
# (21264, 'pop/r&b')
# (21267, 'rock')
# (21267, 'pop/r&b')
# (21207, 'metal')
# (21188, 'rock')
# (21249, 'metal')
# (21108, 'experimental')
# (21232, 'pop/r&b')
# (21232, 'electronic')
# (21142, 'rock')
# (21229, 'electronic')
# (21133, 'experimental')
# (21214, 'pop/r&b')
# (21262, 'rap')
# (21092, 'rock')
# (21132, 'rap')
# (21191, 'rock')
# (21178, 'rock')
# (21053, 'rock')
# (21180, 'electronic')
# (21243, 'pop/r&b')
# (21260, 'rock')
# (21220, 'rock')
# (21124, 'rock')
# (21177, 'experimental')
# (21193, 'rock')
# (21131, 'experimental')
# (21110, 'electronic')
# (21139, 'pop/r&b')
# (21251, 'rap')
# (21056, 'experimental')
# (21204, 'rock')
# (21161, 'rock')
# (21100, None)
# (21162, 'electronic')
# (21154, 'rap')
# (21176, 'rock')
# (21226, 'rap')
# (21121, 'rock')
# (21175, 'rock')
# (21130, 'experimental')
# (21128, 'folk/country')
# (21156, 'rap')
# (21120, 'electronic')
# (21187, 'electronic')
# (21223, 'electronic')
# (21151, 'metal')
# (21155, 'rap')
# (21147, 'pop/r&b')
# (21119, 'rock')
# (21119, 'electronic')
# (21081, 'electronic')
# (21206, 'rock')
# (21096, 'rock')
# (21055, 'rock')
# (21143, 'metal')
# (21196, 'electronic')
# (21183, 'experimental')
# (21091, 'rock')
# (21224, 'rap')
# (21222, 'electronic')
# (21106, 'jazz')
# (21106, 'metal')
# (21211, 'electronic')
# (21182, 'rock')
# (21173, 'pop/r&b')
# (21098, 'pop/r&b')
# (21153, 'rap')
# (21174, 'experimental')
# (21125, 'rock')
# (20980, 'rock')
# (20859, 'rock')
# (21126, 'experimental')
# (21200, 'metal')
# (21097, 'folk/country')
# (21117, 'electronic')
# (21089, 'pop/r&b')
# (21195, 'electronic')
# (21152, 'rock')
# (21197, 'rock')
# (21181, 'electronic')
# (21172, 'rap')
# (21116, 'rock')
# (21171, 'rock')
# (20903, 'rap')
# (21198, 'rock')
# (21013, 'pop/r&b')
# (21148, 'electronic')
# (21149, 'rock')
# (21041, 'electronic')
# (21202, 'rap')
# (21199, 'rap')
# (21150, 'electronic')
# (21054, 'metal')
# (21194, 'rock')
# (21088, 'electronic')
# (21018, 'electronic')
# (21032, 'rock')
# (21052, 'metal')
# (21039, 'rock')
# (21083, 'rock')
# (21186, 'metal')
# (20979, 'rock')
# (21113, 'rap')
# (21086, 'rock')
# (21085, 'electronic')
# (21114, 'experimental')
# (21051, 'electronic')
# (21185, 'rock')
# (21137, 'rock')
# (21038, 'rap')
# (21138, 'rock')
# (21095, 'electronic')
# (21080, 'rap')
# (20432, 'pop/r&b')
# (20966, 'rock')
# (21105, 'jazz')
# (20965, 'rock')
# (21020, 'electronic')
# (21060, 'pop/r&b')
# (21115, 'rock')
# (21028, 'rock')
# (21082, 'electronic')
# (21078, 'electronic')
# (21042, 'rock')
# (21044, 'electronic')
# (21029, 'rock')
# (21079, 'rock')
# (21050, 'electronic')
# (21145, 'rap')
# (21140, 'rock')
# (21122, None)
# (21019, 'rock')
# (21048, 'pop/r&b')
# (21022, 'metal')
# (21166, 'rap')
# (21066, 'rock')
# (21094, 'rap')
# (20975, 'rock')
# (21043, 'rap')
# (21107, 'rap')
# (21077, 'experimental')
# (20914, 'rock')
# (21065, 'rock')
# (21035, 'rock')
# (20950, 'electronic')
# (20995, 'rock')
# (21068, 'electronic')
# (20854, 'experimental')
# (21104, 'pop/r&b')
# (20893, 'rap')
# (21037, 'rock')
# (21129, 'electronic')
# (21049, 'pop/r&b')
# (21034, 'electronic')
# (21101, 'rock')
# (21030, None)
# (20998, 'rap')
# (21076, 'rap')
# (21099, 'rap')
# (21075, 'rap')
# (21009, None)
# (21059, 'electronic')
# (21069, 'pop/r&b')
# (21069, 'electronic')
# (21102, 'rap')
# (20978, 'pop/r&b')
# (21014, 'experimental')
# (20892, 'rock')
# (21073, 'rock')
# (20840, 'rock')
# (21036, 'rock')
# (20949, 'rock')
# (21072, 'pop/r&b')
# (21031, 'electronic')
# (21033, 'pop/r&b')
# (21064, 'rock')
# (20987, 'experimental')
# (21084, 'electronic')
# (20954, 'rap')
# (20825, 'electronic')
# (20960, None)
# (21074, 'pop/r&b')
# (21046, 'folk/country')
# (20994, 'rock')
# (21047, 'rock')
# (20890, 'rap')
# (21015, 'electronic')
# (21024, 'rock')
# (21027, 'jazz')
# (21016, 'rap')
# (21067, 'electronic')
# (21002, 'experimental')
# (21008, 'rock')
# (21007, 'experimental')
# (20913, 'rock')
# (21058, 'rock')
# (21006, 'rock')
# (20880, 'electronic')
# (21011, 'rock')
# (20982, 'rock')
# (20878, 'electronic')
# (20912, 'rock')
# (20977, 'pop/r&b')
# (20930, 'folk/country')
# (21025, 'rap')
# (20989, 'pop/r&b')
# (20964, 'rock')
# (20829, 'rock')
# (21063, 'rock')
# (21026, 'rock')
# (21026, 'pop/r&b')
# (21001, 'metal')
# (21012, 'pop/r&b')
# (20837, 'rock')
# (21005, 'electronic')
# (21003, 'rock')
# (20962, 'rock')
# (21004, 'rock')
# (20957, 'rock')
# (20974, 'rock')
# (20976, 'pop/r&b')
# (20946, 'rock')
# (20993, 'rock')
# (20953, 'electronic')
# (20924, 'rap')
# (20881, 'rock')
# (20891, 'rock')
# (20986, 'rock')
# (20992, 'rock')
# (20931, 'experimental')
# (21023, 'pop/r&b')
# (20991, 'electronic')
# (20973, 'rock')
# (20932, 'rap')
# (20944, 'rock')
# (20706, 'rock')
# (21000, 'rap')
# (20961, 'rock')
# (20877, 'rock')
# (20874, 'electronic')
# (20999, 'pop/r&b')
# (20971, 'rock')
# (20968, 'electronic')
# (20834, 'metal')
# (20951, 'pop/r&b')
# (20943, 'pop/r&b')
# (20981, 'rock')
# (20972, 'rock')
# (20938, None)
# (20875, 'electronic')
# (20970, 'rock')
# (20876, 'rock')
# (20967, 'pop/r&b')
# (20959, 'experimental')
# (20833, 'metal')
# (20922, 'rap')
# (20899, None)
# (20759, 'rock')
# (20790, 'metal')
# (20969, 'rock')
# (20939, 'rock')
# (20940, 'rock')
# (20920, 'folk/country')
# (20945, 'electronic')
# (20803, 'experimental')
# (20985, 'pop/r&b')
# (20985, 'electronic')
# (20926, 'rap')
# (20897, 'rock')
# (20865, 'folk/country')
# (20988, 'rock')
# (20691, 'rock')
# (20746, 'rock')
# (20844, 'rap')
# (20889, 'rock')
# (20909, 'experimental')
# (20898, 'pop/r&b')
# (20941, 'rap')
# (20869, 'rock')
# (20937, 'rock')
# (20873, 'electronic')
# (20872, 'electronic')
# (20870, 'electronic')
# (20915, 'rap')
# (20917, 'rock')
# (20887, 'rap')
# (20925, 'rap')
# (20905, 'rap')
# (20905, 'pop/r&b')
# (20933, 'rock')
# (20923, 'rock')
# (20705, 'folk/country')
# (20747, 'rock')
# (20871, 'experimental')
# (20927, 'rock')
# (20918, 'rock')
# (20686, 'electronic')
# (20935, 'rap')
# (20896, 'rap')
# (20908, 'folk/country')
# (20894, 'rock')
# (20936, 'electronic')
# (20955, 'rap')
# (20767, 'pop/r&b')
# (20895, 'electronic')
# (20907, 'metal')
# (20883, 'rock')
# (20866, 'rock')
# (20839, 'experimental')
# (20906, 'rock')
# (20852, 'electronic')
# (20919, 'rap')
# (20902, 'pop/r&b')
# (20904, 'metal')
# (20867, 'rock')
# (20886, 'rock')
# (20868, 'electronic')
# (20901, 'rap')
# (20819, 'rock')
# (20884, 'rap')
# (20740, 'rock')
# (20853, 'rock')
# (20862, 'rock')
# (20781, 'rock')
# (20863, 'rock')
# (20882, 'rap')
# (20788, 'metal')
# (20861, 'rock')
# (20830, 'global')
# (20864, 'rock')
# (20842, 'rock')
# (20793, 'experimental')
# (20843, 'rap')
# (20701, 'rock')
# (20777, None)
# (20804, 'rock')
# (20716, 'folk/country')
# (20835, 'rock')
# (20807, 'rap')
# (20848, 'pop/r&b')
# (20849, 'electronic')
# (20860, 'electronic')
# (20847, 'rock')
# (20900, 'experimental')
# (20802, 'experimental')
# (20814, 'experimental')
# (20836, 'rock')
# (20668, 'rock')
# (20797, 'electronic')
# (20855, 'pop/r&b')
# (20850, 'rock')
# (20820, 'rock')
# (20702, 'rock')
# (20846, 'rap')
# (20714, 'metal')
# (20827, 'rap')
# (20832, 'electronic')
# (20816, 'jazz')
# (20824, 'electronic')
# (20765, 'pop/r&b')
# (20738, 'electronic')
# (20821, 'folk/country')
# (20838, 'rock')
# (20817, 'rap')
# (20757, 'electronic')
# (20811, 'experimental')
# (20822, 'rock')
# (20810, 'rap')
# (20724, 'metal')
# (20805, 'rock')
# (20801, 'rock')
# (20806, 'rock')
# (20812, 'rock')
# (20766, 'rock')
# (20813, 'rock')
# (20794, 'rock')
# (20792, 'rock')
# (20799, 'rock')
# (20818, 'rock')
# (20800, 'experimental')
# (20798, 'rock')
# (20809, 'pop/r&b')
# (20749, 'electronic')
# (20831, 'electronic')
# (20776, 'electronic')
# (20756, 'electronic')
# (20745, 'rap')
# (20721, 'electronic')
# (20667, 'rock')
# (20697, 'folk/country')
# (20826, 'experimental')
# (20775, 'rock')
# (20648, 'rock')
# (20774, 'rap')
# (20718, 'rock')
# (20795, 'rap')
# (20808, 'electronic')
# (20578, 'rock')
# (20786, 'rock')
# (20787, 'jazz')
# (20772, 'rap')
# (20736, 'rock')
# (20743, 'electronic')
# (20770, 'rock')
# (20653, 'rock')
# (20712, 'rock')
# (20754, 'jazz')
# (20753, None)
# (20796, 'rap')
# (20783, 'pop/r&b')
# (20761, 'rock')
# (20735, 'rock')
# (20791, 'electronic')
# (20779, 'electronic')
# (20762, 'rap')
# (20751, 'rap')
# (20707, 'rock')
# (20722, 'rap')
# (20782, 'electronic')
# (20731, 'rock')
# (20773, 'rock')
# (20755, 'electronic')
# (20729, 'electronic')
# (20778, 'rap')
# (20752, 'electronic')
# (20742, 'rock')
# (20710, 'rock')
# (20728, 'pop/r&b')
# (20769, 'electronic')
# (20734, 'pop/r&b')
# (20780, 'rap')
# (20692, 'rock')
# (20643, 'rock')
# (20709, 'electronic')
# (20680, 'rock')
# (20768, 'rap')
# (20750, 'rap')
# (20719, 'rap')
# (20647, 'rock')
# (20733, 'rap')
# (20723, 'experimental')
# (20608, 'metal')
# (20760, 'electronic')
# (20690, 'rap')
# (20741, 'electronic')
# (20443, 'rock')
# (20443, 'pop/r&b')
# (20443, 'electronic')
# (20689, 'rock')
# (20726, 'rock')
# (20484, 'rock')
# (20574, 'rap')
# (20660, 'rock')
# (20652, 'jazz')
# (20652, 'experimental')
# (20725, 'pop/r&b')
# (20679, 'folk/country')
# (20682, 'folk/country')
# (20688, 'rock')
# (20715, 'rock')
# (20511, 'rock')
# (20687, 'rap')
# (20717, 'pop/r&b')
# (20711, 'rock')
# (20662, 'global')
# (20720, 'rock')
# (20748, 'experimental')
# (20646, 'electronic')
# (20678, 'pop/r&b')
# (20685, 'electronic')
# (20483, 'rock')
# (20671, 'experimental')
# (20666, 'rock')
# (20695, 'electronic')
# (20632, 'folk/country')
# (20703, 'pop/r&b')
# (20694, 'electronic')
# (20699, 'metal')
# (20573, 'jazz')
# (20698, 'experimental')
# (20607, 'metal')
# (20696, None)
# (20623, 'rock')
# (20676, 'electronic')
# (20730, 'pop/r&b')
# (20677, 'electronic')
# (20651, 'metal')
# (20673, 'rock')
# (20601, 'metal')
# (20700, 'pop/r&b')
# (20675, 'electronic')
# (20552, 'metal')
# (20645, 'rock')
# (20644, 'pop/r&b')
# (20642, 'electronic')
# (20665, 'rock')
# (20650, 'electronic')
# (20670, 'rap')
# (20625, 'electronic')
# (20641, 'pop/r&b')
# (20576, 'rock')
# (20683, 'rock')
# (20674, 'electronic')
# (20577, 'rock')
# (20672, 'experimental')
# (20693, 'folk/country')
# (20606, 'rock')
# (20599, 'rock')
# (20669, 'pop/r&b')
# (20291, None)
# (20638, 'experimental')
# (20520, 'rock')
# (20631, 'rock')
# (20655, None)
# (20654, 'rock')
# (20568, 'experimental')
# (20639, 'rock')
# (20640, 'electronic')
# (20600, 'electronic')
# (20637, 'pop/r&b')
# (20664, 'rap')
# (20664, 'pop/r&b')
# (20465, 'rock')
# (20598, 'metal')
# (20657, 'rock')
# (20636, 'electronic')
# (20663, 'rock')
# (20658, 'rock')
# (20619, 'metal')
# (20635, 'pop/r&b')
# (20565, 'folk/country')
# (20519, 'global')
# (20519, 'pop/r&b')
# (20659, 'rap')
# (20407, 'rock')
# (20634, 'electronic')
# (20656, 'pop/r&b')
# (20605, 'pop/r&b')
# (20597, 'folk/country')
# (20538, 'global')
# (20538, 'electronic')
# (20564, 'rap')
# (20549, 'electronic')
# (20458, 'electronic')
# (20412, 'rock')
# (20551, 'rock')
# (20563, 'experimental')
# (20547, 'metal')
# (20661, 'rap')
# (20545, None)
# (20613, 'rock')
# (20550, 'electronic')
# (20630, 'electronic')
# (20624, 'rock')
# (20633, 'rap')
# (20572, 'rock')
# (20614, 'electronic')
# (20611, 'rock')
# (20515, None)
# (20553, 'electronic')
# (20610, 'rock')
# (20622, 'rap')
# (20612, 'rock')
# (20590, 'rock')
# (20561, 'rap')
# (20596, 'rock')
# (20621, 'rap')
# (20581, 'metal')
# (20620, 'pop/r&b')
# (20571, 'electronic')
# (20589, 'electronic')
# (20602, 'electronic')
# (20580, 'electronic')
# (20457, 'experimental')
# (20441, 'rock')
# (20442, 'rock')
# (20626, 'electronic')
# (20604, 'rock')
# (20506, 'electronic')
# (20570, 'electronic')
# (20609, 'rock')
# (20569, 'rock')
# (20562, 'rock')
# (20339, 'rock')
# (20533, 'rock')
# (20505, 'jazz')
# (20433, 'folk/country')
# (20548, 'experimental')
# (20585, 'pop/r&b')
# (20464, 'rock')
# (20305, 'folk/country')
# (20486, 'experimental')
# (20615, 'pop/r&b')
# (20488, 'experimental')
# (20603, 'metal')
# (20544, None)
# (20546, 'experimental')
# (20595, 'rock')
# (20463, 'experimental')
# (20415, 'electronic')
# (20499, 'rap')
# (20440, 'electronic')
# (20540, 'folk/country')
# (20435, 'rap')
# (20518, 'pop/r&b')
# (20459, 'electronic')
# (20510, 'rap')
# (20423, 'rock')
# (20462, 'electronic')
# (20579, 'electronic')
# (20524, 'pop/r&b')
# (20485, 'rock')
# (20414, 'rock')
# (20481, 'folk/country')
# (20586, 'rock')
# (20434, 'rock')
# (20477, 'rock')
# (20560, 'folk/country')
# (20557, 'jazz')
# (20584, 'rock')
# (20555, 'pop/r&b')
# (20461, 'rock')
# (20526, 'experimental')
# (20448, 'rock')
# (20290, 'rock')
# (20421, 'rock')
# (20439, 'rock')
# (20508, 'electronic')
# (20554, 'rock')
# (20517, 'rock')
# (20543, 'pop/r&b')
# (20559, 'electronic')
# (20446, None)
# (20349, 'rock')
# (20330, 'folk/country')
# (20556, 'rap')
# (20509, 'pop/r&b')
# (20512, None)
# (20542, None)
# (20398, 'rock')
# (20502, 'rap')
# (20444, 'electronic')
# (20445, 'rock')
# (20288, 'rock')
# (20476, 'experimental')
# (20397, 'rap')
# (20504, 'rock')
# (20452, 'rock')
# (20396, 'rock')
# (20503, 'electronic')
# (20352, 'metal')
# (20536, 'rap')
# (20537, 'experimental')
# (20410, 'electronic')
# (20395, 'rock')
# (20507, 'rock')
# (20521, 'pop/r&b')
# (20469, 'rock')
# (20539, 'rock')
# (20346, 'pop/r&b')
# (20497, 'electronic')
# (20531, 'rap')
# (20527, 'pop/r&b')
# (20495, 'rock')
# (20289, 'experimental')
# (20475, 'folk/country')
# (20431, 'electronic')
# (20494, 'rap')
# (20529, 'rap')
# (20408, 'rock')
# (20456, 'rap')
# (20514, 'metal')
# (20498, 'pop/r&b')
# (20420, 'rock')
# (20530, 'rock')
# (20523, 'electronic')
# (20528, 'rap')
# (20496, 'metal')
# (20454, 'pop/r&b')
# (20535, None)
# (20353, 'rock')
# (20500, 'metal')
# (20522, 'pop/r&b')
# (20362, 'rock')
# (20472, 'rock')
# (20513, 'electronic')
# (20329, 'metal')
# (20480, 'metal')
# (20351, 'rock')
# (20487, 'electronic')
# (20143, 'rock')
# (20394, 'rock')
# (20482, 'jazz')
# (20493, 'rap')
# (20382, 'rap')
# (20368, 'rock')
# (20460, None)
# (20403, 'rock')
# (20419, 'experimental')
# (20384, 'rock')
# (20417, 'folk/country')
# (20418, 'electronic')
# (20467, 'rock')
# (20428, 'rock')
# (20430, 'experimental')
# (20297, 'electronic')
# (20453, 'rock')
# (20478, 'electronic')
# (20380, 'rap')
# (20380, 'pop/r&b')
# (20429, 'electronic')
# (20468, 'rock')
# (20392, 'rock')
# (20401, 'rock')
# (20473, 'rap')
# (20474, 'rock')
# (20402, 'rock')
# (20406, 'rap')
# (20393, 'rock')
# (20203, 'folk/country')
# (20466, 'rap')
# (20471, 'experimental')
# (20348, None)
# (20286, 'electronic')
# (20391, 'rap')
# (20357, 'rock')
# (20367, 'rock')
# (20363, 'rock')
# (20345, 'rock')
# (20437, 'rock')
# (20470, 'rap')
# (20354, 'rock')
# (20416, 'rock')
# (20387, None)
# (20385, 'electronic')
# (20409, 'experimental')
# (20400, 'electronic')
# (20132, 'rock')
# (20447, 'electronic')
# (20381, 'rock')
# (20309, None)
# (20285, 'rock')
# (20331, 'electronic')
# (20436, 'rock')
# (20213, 'rock')
# (20411, 'rock')
# (20373, 'rap')
# (20212, 'rock')
# (20347, 'rock')
# (20450, 'electronic')
# (20343, 'rock')
# (20425, 'rap')
# (20438, 'rap')
# (20372, 'rock')
# (20334, 'rock')
# (20426, 'pop/r&b')
# (20304, 'electronic')
# (20371, 'rock')
# (20427, 'experimental')
# (20451, 'rap')
# (20451, 'experimental')
# (20244, 'electronic')
# (20405, 'electronic')
# (20389, 'rock')
# (20386, None)
# (20218, 'folk/country')
# (20360, 'electronic')
# (20215, 'folk/country')
# (20364, 'rock')
# (20379, 'electronic')
# (20424, 'rap')
# (20377, 'rock')
# (20355, 'rap')
# (20399, 'electronic')
# (20375, 'rock')
# (20313, 'metal')
# (20296, 'electronic')
# (20383, 'metal')
# (20369, 'rock')
# (20376, 'pop/r&b')
# (20404, 'rap')
# (20295, 'electronic')
# (20413, 'rap')
# (20310, 'rock')
# (20287, 'rock')
# (20422, 'rap')
# (20378, 'rock')
# (20243, 'rock')
# (20211, 'folk/country')
# (20284, 'rock')
# (20268, 'rock')
# (20076, 'rock')
# (20252, 'rock')
# (20358, 'rock')
# (20374, 'rock')
# (20321, 'rock')
# (20388, 'pop/r&b')
# (20322, 'rock')
# (20365, 'pop/r&b')
# (20361, 'rock')
# (20390, 'rap')
# (20370, 'rock')
# (20323, 'electronic')
# (20338, 'rock')
# (20356, 'rap')
# (20174, 'rock')
# (20337, 'rap')
# (20340, 'rock')
# (20366, 'rock')
# (20325, 'experimental')
# (20335, 'rock')
# (20324, 'global')
# (20324, 'electronic')
# (20342, 'pop/r&b')
# (20298, 'pop/r&b')
# (20336, 'rock')
# (20153, 'rock')
# (20242, 'electronic')
# (20318, 'rap')
# (20261, 'experimental')
# (20269, 'metal')
# (20293, 'pop/r&b')
# (20319, 'electronic')
# (20301, 'rap')
# (20204, 'rock')
# (20315, 'metal')
# (20299, None)
# (20266, None)
# (20312, 'experimental')
# (20273, 'metal')
# (20333, 'rap')
# (20307, 'rap')
# (20177, 'electronic')
# (20239, 'electronic')
# (20311, 'folk/country')
# (20320, 'rock')
# (20327, 'rap')
# (20241, 'rock')
# (20332, 'electronic')
# (20202, 'rock')
# (20267, 'metal')
# (20259, 'rock')
# (20278, 'experimental')
# (20178, 'rock')
# (20303, 'metal')
# (20317, 'rap')
# (20240, 'rock')
# (20185, 'rock')
# (20292, None)
# (20234, 'rock')
# (20302, 'folk/country')
# (20326, None)
# (20308, 'rock')
# (20272, 'metal')
# (20294, 'electronic')
# (20277, 'electronic')
# (20314, 'rock')
# (20201, 'rock')
# (20316, 'rock')
# (20034, 'electronic')
# (20105, 'rock')
# (20276, 'electronic')
# (20098, 'metal')
# (20262, 'rock')
# (20257, 'rock')
# (20265, 'experimental')
# (20306, 'electronic')
# (20179, 'rock')
# (20200, 'folk/country')
# (20264, 'rock')
# (20209, 'rock')
# (20281, 'rap')
# (20238, 'rock')
# (20283, 'electronic')
# (20248, None)
# (20260, None)
# (20280, 'electronic')
# (20300, 'rap')
# (20233, 'rock')
# (20256, 'metal')
# (20217, 'rock')
# (20220, 'rap')
# (20198, 'folk/country')
# (20227, 'rock')
# (20149, 'rock')
# (20282, 'rock')
# (19834, 'rock')
# (20199, 'folk/country')
# (20236, 'rock')
# (20237, 'rock')
# (20235, 'rock')
# (20279, 'electronic')
# (20046, 'metal')
# (20197, 'rock')
# (20270, 'global')
# (20128, 'electronic')
# (20232, 'rock')
# (20180, 'rock')
# (20275, 'rock')
# (20183, 'electronic')
# (20249, 'folk/country')
# (20097, 'rock')
# (20188, None)
# (20255, 'rock')
# (20206, 'electronic')
# (20230, 'rock')
# (20251, 'rock')
# (20161, 'rock')
# (20229, 'electronic')
# (20231, 'experimental')
# (20263, 'rock')
# (20271, 'rap')
# (20155, 'rock')
# (20254, 'electronic')
# (20169, 'rock')
# (20258, 'rock')
# (20196, 'rap')
# (20196, 'jazz')
# (20095, 'rock')
# (20195, 'electronic')
# (20158, 'rock')
# (20226, 'electronic')
# (20189, 'electronic')
# (20075, 'electronic')
# (20096, 'rock')
# (20123, 'rock')
# (20224, 'pop/r&b')
# (20122, 'rock')
# (20182, 'rock')
# (20208, 'rock')
# (20250, 'rock')
# (20225, 'metal')
# (20173, 'rock')
# (20214, 'rock')
# (20210, 'experimental')
# (20253, 'pop/r&b')
# (20219, 'rock')
# (20074, 'experimental')
# (20228, 'rap')
# (20147, 'rock')
# (20151, 'electronic')
# (20223, 'rap')
# (20131, 'rock')
# (20073, 'experimental')
# (20108, 'rock')
# (20184, 'electronic')
# (20172, 'rock')
# (20245, 'experimental')
# (20145, 'global')
# (20145, 'experimental')
# (20094, 'metal')
# (20187, 'rock')
# (20142, 'rock')
# (20091, 'experimental')
# (20025, 'jazz')
# (20191, 'rock')
# (20205, None)
# (20101, 'rock')
# (20221, 'rock')
# (20192, 'pop/r&b')
# (20134, 'electronic')
# (20144, 'rock')
# (20193, 'rock')
# (20190, 'rock')
# (20146, 'rap')
# (20106, 'rock')
# (20168, 'rock')
# (20194, 'rock')
# (20092, 'folk/country')
# (20068, 'rock')
# (20093, 'folk/country')
# (20129, 'rock')
# (20141, 'rock')
# (20186, 'rap')
# (20175, 'pop/r&b')
# (20061, 'rock')
# (20167, 'rock')
# (20207, 'rap')
# (20166, 'rap')
# (20160, 'rock')
# (20171, None)
# (20126, 'metal')
# (20090, 'jazz')
# (20130, 'folk/country')
# (20140, 'rock')
# (20159, 'electronic')
# (20116, 'metal')
# (20071, 'electronic')
# (20156, 'electronic')
# (20070, 'rap')
# (19970, 'metal')
# (20089, 'rock')
# (20118, 'global')
# (20118, 'experimental')
# (20088, 'rock')
# (20176, 'rap')
# (20049, 'folk/country')
# (20072, 'electronic')
# (20120, 'rock')
# (20181, 'pop/r&b')
# (20181, 'electronic')
# (20170, 'pop/r&b')
# (20069, 'pop/r&b')
# (20067, 'electronic')
# (20157, 'rock')
# (20086, 'rock')
# (20133, 'rap')
# (19958, 'pop/r&b')
# (20139, 'rock')
# (20154, 'rap')
# (20135, 'rock')
# (20121, 'pop/r&b')
# (20136, 'rock')
# (20082, None)
# (20138, 'rock')
# (20148, 'rock')
# (20100, 'rock')
# (20119, 'rock')
# (20152, 'electronic')
# (20150, 'rap')
# (20083, 'rock')
# (20060, 'rock')
# (20085, 'rock')
# (20065, 'rock')
# (20084, 'experimental')
# (20113, 'rap')
# (20104, 'pop/r&b')
# (20125, 'rap')
# (20117, 'pop/r&b')
# (20127, None)
# (20080, 'rock')
# (20114, 'electronic')
# (20115, 'folk/country')
# (20109, 'rap')
# (19948, 'rock')
# (20103, 'electronic')
# (20107, 'electronic')
# (20064, 'electronic')
# (20124, 'rap')
# (20112, 'rock')
# (20102, 'rap')
# (20102, 'experimental')
# (20059, 'rap')
# (20063, 'electronic')
# (20081, 'electronic')
# (20111, None)
# (20079, 'electronic')
# (20042, None)
# (20087, 'rap')
# (20039, 'electronic')
# (20047, 'rock')
# (20078, 'pop/r&b')
# (20058, 'rap')
# (20066, 'pop/r&b')
# (20057, 'electronic')
# (19889, None)
# (20056, 'global')
# (20038, 'electronic')
# (20054, 'rap')
# (20053, 'electronic')
# (20048, 'rap')
# (20062, 'rap')
# (19956, 'rock')
# (20052, 'rap')
# (20051, 'rock')
# (20045, 'rap')
# (20023, 'rock')
# (20014, 'electronic')
# (20050, 'pop/r&b')
# (19976, None)
# (19908, 'folk/country')
# (19908, 'metal')
# (20001, None)
# (19994, None)
# (20030, 'rock')
# (20031, 'rock')
# (20037, 'experimental')
# (20040, None)
# (19744, None)
# (20032, 'experimental')
# (20024, None)
# (19951, 'metal')
# (20019, None)
# (19839, None)
# (20044, 'electronic')
# (20028, 'electronic')
# (19973, 'pop/r&b')
# (19973, 'electronic')
# (19987, None)
# (20041, None)
# (20043, 'rap')
# (19984, 'global')
# (19984, 'jazz')
# (19984, 'experimental')
# (19984, 'electronic')
# (20029, 'rap')
# (20029, 'pop/r&b')
# (20022, 'folk/country')
# (20022, 'metal')
# (19972, 'metal')
# (19972, 'experimental')
# (20017, 'rock')
# (20033, 'rock')
# (19988, 'rock')
# (19988, 'electronic')
# (19995, 'rock')
# (20000, None)
# (19805, None)
# (20016, 'rock')
# (20035, 'electronic')
# (19876, None)
# (19877, None)
# (20036, None)
# (20018, 'electronic')
# (19985, None)
# (19953, 'global')
# (20026, 'electronic')
# (19997, 'rap')
# (20011, None)
# (19986, None)
# (19947, None)
# (19993, None)
# (20015, 'rock')
# (20027, 'rap')
# (19983, 'electronic')
# (19921, 'rock')
# (19841, None)
# (20021, 'electronic')
# (19907, 'rock')
# (19935, 'rock')
# (19920, 'rock')
# (19920, 'experimental')
# (19941, 'rap')
# (20020, 'rock')
# (20004, 'rock')
# (19949, 'rock')
# (19966, None)
# ...
# (2950, 'rock')
# (2950, 'electronic')
# (4936, 'rock')
# (7598, 'rock')
# (1701, 'rock')
# (1701, 'metal')
# (8188, 'rock')
# (6652, 'rock')
# (4040, 'rock')
# (8580, 'rock')
# (164, 'rock')
# (164, 'metal')
# (118, 'rock')
# (7335, None)
# (1015, 'rock')
# (6461, 'rock')
# (5502, 'rock')
# (5502, 'electronic')
# (4906, 'rock')
# (8155, 'electronic')
# (7941, 'rock')
# (7941, 'experimental')
# (6448, 'electronic')
# (1501, 'rock')
# (7113, 'rock')
# (4897, None)
# (669, 'rock')
# (570, 'jazz')
# (570, 'experimental')
# (8570, 'rock')
# (8924, 'jazz')
# (8924, 'experimental')
# (8875, 'global')
# (8875, 'electronic')
# (7447, 'electronic')
# (4782, 'rock')
# (6238, 'rock')
# (8504, 'rock')
# (5070, 'rock')
# (2957, 'rock')
# (4306, 'rock')
# (7662, 'rock')
# (1440, None)
# (510, 'rock')
# (510, 'electronic')
# (7565, 'rock')
# (602, 'rap')
# (8400, 'rock')
# (8144, 'rock')
# (5046, 'pop/r&b')
# (5756, None)
# (5757, None)
# (5754, None)
# (7438, 'jazz')
# (3834, 'electronic')
# (5533, 'rock')
# (6659, 'rock')
# (3800, 'rock')
# (4738, 'rock')
# (4738, 'electronic')
# (4488, None)
# (697, None)
# (3524, 'rock')
# (3524, 'electronic')
# (5952, 'rock')
# (177, 'metal')
# (5232, 'rock')
# (6335, 'electronic')
# (80, 'electronic')
# (5085, 'rock')
# (2703, 'rock')
# (8645, 'rock')
# (6066, 'experimental')
# (6066, 'electronic')
# (6417, 'rock')
# (6417, 'experimental')
# (8011, 'electronic')
# (2669, 'rock')
# (2669, 'electronic')
# (1231, 'rock')
# (4627, 'rock')
# (6692, 'rock')
# (6692, 'electronic')
# (7445, 'electronic')
# (8074, 'rock')
# (1284, 'rap')
# (1640, 'rock')
# (8104, 'metal')
# (2283, 'rock')
# (2283, 'electronic')
# (8611, 'rock')
# (6748, 'rock')
# (1060, 'rock')
# (1024, 'rock')
# (1024, 'metal')
# (4677, 'rock')
# (4320, 'rock')
# (5365, 'rock')
# (144, 'rock')
# (2757, 'rap')
# (5461, 'electronic')
# (4269, 'rock')
# (4269, 'metal')
# (1638, 'pop/r&b')
# (8427, 'global')
# (2964, 'pop/r&b')
# (2166, 'rock')
# (6013, 'rock')
# (6013, 'experimental')
# (2860, 'rock')
# (2860, 'metal')
# (2860, 'experimental')
# (561, 'rock')
# (1517, 'rap')
# (2830, 'rock')
# (8373, 'rock')
# (8494, 'electronic')
# (7311, 'rock')
# (7280, 'rock')
# (5771, 'rock')
# (4727, 'jazz')
# (4727, 'electronic')
# (3593, 'rock')
# (6812, 'rock')
# (6812, 'metal')
# (183, None)
# (8685, 'folk/country')
# (701, 'folk/country')
# (2336, 'rock')
# (2262, 'electronic')
# (5151, 'experimental')
# (4633, 'rock')
# (4633, 'electronic')
# (11667, 'rock')
# (1394, None)
# (186, None)
# (2767, None)
# (3916, 'rock')
# (8231, 'rock')
# (7922, 'electronic')
# (5295, 'rock')
# (5295, 'pop/r&b')
# (8008, 'rock')
# (8008, 'experimental')
# (4459, 'rock')
# (5072, 'rock')
# (8699, 'rock')
# (5257, 'rock')
# (5257, 'electronic')
# (7213, 'folk/country')
# (1654, 'electronic')
# (2134, 'electronic')
# (3839, 'rock')
# (4448, 'rock')
# (8555, 'jazz')
# (8555, 'electronic')
# (789, 'rock')
# (781, 'rock')
# (2419, 'rock')
# (5951, 'rock')
# (4787, 'rock')
# (253, 'rock')
# (253, 'experimental')
# (6316, 'rock')
# (1672, 'rock')
# (400, 'rock')
# (270, 'rock')
# (7470, 'rock')
# (7470, 'electronic')
# (5387, 'rock')
# (6026, 'electronic')
# (1249, 'pop/r&b')
# (4791, 'rock')
# (7429, 'rock')
# (3529, 'rock')
# (3702, 'rock')
# (4617, 'rock')
# (4617, 'electronic')
# (5782, None)
# (6726, 'rock')
# (6972, 'rock')
# (6972, 'electronic')
# (202, 'folk/country')
# (8114, 'rock')
# (8114, 'experimental')
# (245, 'folk/country')
# (4205, 'rock')
# (8154, 'electronic')
# (4234, 'experimental')
# (4916, 'rock')
# (5057, 'rock')
# (2429, 'rock')
# (4704, 'rock')
# (4704, 'electronic')
# (7462, 'rock')
# (4892, 'rock')
# (7122, 'rock')
# (7122, 'metal')
# (8500, 'rock')
# (8500, 'electronic')
# (1252, 'rock')
# (7117, 'jazz')
# (7117, 'experimental')
# (213, 'global')
# (213, 'pop/r&b')
# (1307, 'rock')
# (4523, 'rock')
# (5356, 'rock')
# (32, None)
# (33, 'rock')
# (132, 'rock')
# (132, 'electronic')
# (115, 'rap')
# (115, 'pop/r&b')
# (6965, 'electronic')
# (7282, 'rock')
# (106, 'pop/r&b')
# (110, 'rock')
# (110, 'metal')
# (17, 'rock')
# (17, 'rap')
# (12, 'rock')
# (12, 'metal')
# (5217, 'rock')
# (5217, 'experimental')
# (5159, 'folk/country')
# (5159, 'electronic')
# (360, 'electronic')
# (2856, 'rock')
# (2856, 'electronic')
# (139, None)
# (3373, 'rock')
# (835, 'electronic')
# (4403, 'rock')
# (8869, 'rock')
# (325, None)
# (51, 'experimental')
# (51, 'electronic')
# (1957, None)
# (4776, 'pop/r&b')
# (6469, 'rock')
# (949, None)
# (2677, 'pop/r&b')
# (2677, 'electronic')
# (5798, 'rock')
# (830, 'rock')
# (1414, 'electronic')
# (2992, 'rock')
# (2992, 'metal')
# (7205, 'rock')
# (4926, 'rock')
# (5300, 'electronic')
# (3861, 'rock')
# (5930, 'rock')
# (7336, None)
# (4139, None)
# (4225, 'jazz')
# (4225, 'pop/r&b')
# (4225, 'electronic')
# (682, 'rock')
# (1539, 'rock')
# (5273, 'electronic')
# (3008, 'electronic')
# (7681, 'rock')
# (7681, 'global')
# (7681, 'experimental')
# (7681, 'electronic')
# (8223, 'electronic')
# (3061, 'rock')
# (3756, 'rock')
# (6626, None)
# (2846, 'rock')
# (2231, 'rock')
# (8329, 'rock')
# (87, 'rock')
# (87, 'electronic')
# (557, 'rock')
# (557, 'electronic')
# (3489, 'rock')
# (4385, 'rock')
# (4385, 'jazz')
# (4385, 'metal')
# (3118, 'rock')
# (7427, 'rock')
# (8121, None)
# (2842, 'rock')
# (2842, 'experimental')
# (2842, 'electronic')
# (4187, 'rock')
# (4187, 'experimental')
# (3400, 'electronic')
# (1472, 'pop/r&b')
# (5453, 'rock')
# (4548, None)
# (6723, 'electronic')
# (2651, 'rock')
# (2651, 'experimental')
# (7622, 'rock')
# (4230, 'electronic')
# (8552, 'rock')
# (4657, 'rock')
# (3704, 'folk/country')
# (1947, None)
# (1662, 'rock')
# (7988, 'rock')
# (7988, 'rap')
# (7988, 'metal')
# (7988, 'electronic')
# (805, 'rock')
# (6727, 'rock')
# (5296, 'rock')
# (5296, 'pop/r&b')
# (5793, 'jazz')
# (5793, 'electronic')
# (2414, 'rock')
# (2414, 'metal')
# (2414, 'experimental')
# (6656, 'rock')
# (762, 'rock')
# (526, 'rock')
# (7648, 'electronic')
# (700, 'folk/country')
# (5424, 'jazz')
# (5424, 'pop/r&b')
# (5424, 'electronic')
# (1332, 'folk/country')
# (7040, 'rock')
# (7040, 'experimental')
# (7657, 'rock')
# (5807, 'rock')
# (5198, 'rock')
# (8165, 'rock')
# (6295, 'rock')
# (3475, 'pop/r&b')
# (4328, 'rock')
# (3504, 'rock')
# (3504, 'electronic')
# (1655, 'electronic')
# (6352, 'rock')
# (6352, 'electronic')
# (2156, 'rock')
# (1286, 'rock')
# (6445, 'pop/r&b')
# (6445, 'experimental')
# (7209, None)
# (1653, 'pop/r&b')
# (7316, 'rock')
# (8348, 'electronic')
# (8874, 'global')
# (8874, 'electronic')
# (8136, 'rock')
# (8136, 'metal')
# (2741, 'rock')
# (673, 'rock')
# (7214, 'rock')
# (36, 'rock')
# (3804, 'rock')
# (6305, 'rock')
# (3577, 'electronic')
# (5060, 'rock')
# (5512, None)
# (4270, 'rock')
# (4270, 'metal')
# (3590, 'rock')
# (729, 'pop/r&b')
# (729, 'electronic')
# (5268, 'rock')
# (5268, 'experimental')
# (4632, 'rock')
# (4632, 'electronic')
# (8719, 'electronic')
# (3616, 'electronic')
# (5368, 'rock')
# (8004, 'jazz')
# (8004, 'pop/r&b')
# (8004, 'electronic')
# (7439, 'jazz')
# (2493, 'rock')
# (4501, 'rock')
# (1011, 'rock')
# (7466, 'rock')
# (4047, 'rock')
# (6425, 'rock')
# (11669, 'rock')
# (5091, 'rock')
# (6418, 'rock')
# (6418, 'experimental')
# (8093, 'rock')
# (5981, None)
# (1362, 'rock')
# (1362, 'metal')
# (7107, 'rock')
# (7940, 'rock')
# (7940, 'experimental')
# (509, 'rock')
# (509, 'electronic')
# (2645, 'rock')
# (2292, 'rock')
# (7279, 'rock')
# (691, 'rock')
# (691, 'metal')
# (691, 'experimental')
# (6856, 'rock')
# (4437, 'electronic')
# (5509, 'rock')
# (5509, 'metal')
# (3737, 'rock')
# (3737, 'pop/r&b')
# (5944, 'rock')
# (508, 'rock')
# (508, 'electronic')
# (7563, 'rock')
# (7972, 'jazz')
# (7972, 'electronic')
# (8594, 'rock')
# (8087, 'jazz')
# (8087, 'electronic')
# (7079, 'rock')
# (11665, 'rock')
# (4747, 'rock')
# (4051, 'rock')
# (8401, 'rock')
# (6331, 'electronic')
# (273, 'rock')
# (7070, None)
# (5327, 'rock')
# (1498, 'rock')
# (3581, 'rock')
# (3581, 'pop/r&b')
# (3581, 'experimental')
# (1964, None)
# (8201, None)
# (278, 'rock')
# (902, 'rock')
# (1264, 'rock')
# (6791, None)
# (5957, 'rock')
# (5957, 'electronic')
# (6610, 'rap')
# (6369, None)
# (6970, 'rock')
# (6970, 'electronic')
# (1359, 'rock')
# (7601, 'rock')
# (3824, 'rock')
# (3824, 'electronic')
# (7864, None)
# (1700, 'rock')
# (1700, 'metal')
# (6371, 'electronic')
# (2183, 'pop/r&b')
# (724, 'pop/r&b')
# (1428, 'rock')
# (601, 'rap')
# (5358, 'rock')
# (4524, 'rock')
# (4325, 'rock')
# (3545, 'rock')
# (3545, 'experimental')
# (804, 'rock')
# (274, 'rock')
# (85, 'rock')
# (4407, 'electronic')
# (7090, 'rock')
# (7583, 'rock')
# (256, 'rock')
# (256, 'experimental')
# (7147, 'rock')
# (4330, 'rap')
# (648, None)
# (5950, 'rock')
# (5231, 'rock')
# (631, 'rock')
# (2836, 'rock')
# (6735, 'rock')
# (941, 'rock')
# (8734, 'rock')
# (1348, 'rock')
# (1441, 'pop/r&b')
# (1441, 'electronic')
# (8830, 'rock')
# (8830, 'electronic')
# (8582, 'jazz')
# (8582, 'experimental')
# (7959, 'jazz')
# (7959, 'electronic')
# (7992, 'rock')
# (6649, 'rock')
# (6649, 'electronic')
# (7496, 'rock')
# (7496, 'experimental')
# (8082, 'jazz')
# (8082, 'electronic')
# (4796, 'rock')
# (4796, 'experimental')
# (3009, 'electronic')
# (5377, 'rock')
# (7885, None)
# (296, 'electronic')
# (2678, 'pop/r&b')
# (2678, 'electronic')
# (2267, 'rock')
# (4852, 'electronic')
# (4109, 'rock')
# (7437, 'jazz')
# (965, 'jazz')
# (992, 'rock')
# (1229, 'rock')
# (7949, 'electronic')
# (4063, 'rock')
# (6327, 'rock')
# (4221, 'rock')
# (8133, 'rock')
# (8133, 'metal')
# (1437, None)
# (1513, 'rock')
# (1513, 'experimental')
# (1513, 'electronic')
# (742, 'pop/r&b')
# (6474, 'rock')
# (8604, 'rock')
# (8604, 'experimental')
# (2384, 'jazz')
# (2384, 'metal')
# (2384, 'electronic')
# (5692, 'rock')
# (5692, 'electronic')
# (692, 'pop/r&b')
# (616, 'rock')
# (7342, 'rock')
# (566, 'rap')
# (1226, 'rock')
# (1226, 'global')
# (1226, 'experimental')
# (2323, 'rock')
# (7007, 'electronic')
# (6495, 'rock')
# (3931, 'rock')
# (3931, 'metal')
# (7239, 'rock')
# (6307, 'rock')
# (5018, None)
# (5056, 'rock')
# (7115, 'jazz')
# (7115, 'experimental')
# (1013, 'rock')
# (4641, 'rock')
# (4641, 'jazz')
# (4641, 'electronic')
# (6428, 'rock')
# (5716, 'rock')
# (5716, 'metal')
# (2959, 'rock')
# (302, 'rock')
# (7416, 'rock')
# (968, 'rock')
# (8143, 'rock')
# (3151, 'rock')
# (3151, 'metal')
# (3402, 'electronic')
# (5971, 'rock')
# (5971, 'experimental')
# (1017, 'pop/r&b')
# (1017, 'electronic')
# (2329, 'rock')
# (2227, 'rock')
# (946, 'electronic')
# (1344, 'rock')
# (2368, 'electronic')
# (4698, 'global')
# (4896, 'rock')
# (8840, 'rock')
# (8840, 'experimental')
# (11828, 'rock')
# (185, 'global')
# (3594, 'rock')
# (7165, None)
# (7267, 'rock')
# (7284, 'rock')
# (7400, 'rock')
# (7400, 'experimental')
# (5223, 'rock')
# (3007, 'electronic')
# (905, 'rock')
# (905, 'metal')
# (1564, 'rap')
# (5226, 'rock')
# (7865, None)
# (2398, 'rock')
# (7436, 'jazz')
# (6603, 'rock')
# (6603, 'experimental')
# (7195, 'rock')
# (7275, 'rock')
# (11769, 'global')
# (6426, 'rock')
# (600, 'rock')
# (321, 'electronic')
# (1241, 'rock')
# (1247, 'electronic')
# (5147, 'rock')
# (2496, 'rock')
# (2496, 'metal')
# (2496, 'electronic')
# (11792, 'rock')
# (4621, 'rap')
# (8065, 'rock')
# (8147, 'rock')
# (863, 'experimental')
# (7486, 'rock')
# (74, 'electronic')
# (5827, 'experimental')
# (5459, 'electronic')
# (7980, None)
# (2816, 'rock')
# (8870, 'rock')
# (8502, 'rock')
# (209, 'rap')
# (209, 'electronic')
# (696, 'rock')
# (6436, 'rock')
# (8669, 'rock')
# (2173, 'electronic')
# (8010, 'electronic')
# (1652, 'pop/r&b')
# (1935, None)
# (7619, 'rock')
# (7619, 'experimental')
# (8190, 'rock')
# (667, 'rock')
# (6833, 'rap')
# (779, 'rock')
# (11829, 'rock')
# (4256, 'rock')
# (7344, 'rock')
# (1671, 'rock')
# (146, 'rock')
# (11798, 'rock')
# (11798, 'electronic')
# (3124, 'rock')
# (8460, 'electronic')
# (5974, 'rock')
# (199, 'rock')
# (6003, 'rock')
# (5494, 'rock')
# (5494, 'electronic')
# (4452, 'rock')
# (1399, 'pop/r&b')
# (5361, 'rock')
# (4246, 'rock')
# (7334, None)
# (7177, 'folk/country')
# (286, 'pop/r&b')
# (286, 'electronic')
# (3509, 'electronic')
# (268, 'rock')
# (268, 'metal')
# (268, 'experimental')
# (3152, 'rock')
# (385, 'electronic')
# (7521, 'rock')
# (4749, 'rock')
# (1578, 'rock')
# (1578, 'electronic')
# (5086, 'rock')
# (8832, 'rock')
# (8832, 'electronic')
# (8334, 'rock')
# (8334, 'experimental')
# (3749, 'rock')
# (6622, 'rap')
# (6638, 'electronic')
# (8222, 'electronic')
# (2494, 'rock')
# (7461, 'rock')
# (8063, 'rock')
# (247, 'rock')
# (3527, 'rock')
# (6247, 'electronic')
# (8360, 'rock')
# (4212, 'rock')
# (4212, 'metal')
# (8361, 'rock')
# (2259, None)
# (1271, 'rock')
# (1271, 'experimental')
# (942, 'rock')
# (4917, 'rock')
# (3855, 'rock')
# (5053, 'rock')
# (4703, 'rock')
# (4703, 'electronic')
# (5227, 'rock')
# (3119, 'rock')
# (2963, 'electronic')
# (4305, 'rock')
# (8395, None)
# (3808, 'rock')
# (3808, 'electronic')
# (4417, 'electronic')
# (4062, 'rock')
# (6467, 'rock')
# (684, 'rock')
# (8347, 'electronic')
# (7658, 'rock')
# (8640, 'rock')
# (5440, 'rap')
# (1523, 'rock')
# (7235, 'electronic')
# (8569, 'electronic')
# (8597, 'rock')
# (8597, 'experimental')
# (6296, 'rock')
# (881, 'rock')
# (8129, 'rock')
# (3193, 'rock')
# (3193, 'electronic')
# (699, 'folk/country')
# (2338, 'rock')
# (1558, 'rock')
# (1558, 'experimental')
# (6642, 'rock')
# (2855, 'rock')
# (2855, 'electronic')
# (3546, 'rock')
# (3546, 'experimental')
# (5519, 'rock')
# (6348, 'electronic')
# (281, 'rock')
# (281, 'metal')
# (7303, 'rock')
# (1004, 'rock')
# (1004, 'electronic')
# (1357, 'rock')
# (5799, 'rock')
# (4910, 'rock')
# (4910, 'pop/r&b')
# (4910, 'folk/country')
# (3430, 'rock')
# (3430, 'metal')
# (4676, 'rock')
# (4880, 'rock')
# (7498, 'rock')
# (7498, 'experimental')
# (3748, 'rock')
# (4291, 'rock')
# (3785, 'folk/country')
# (7323, 'electronic')
# (1467, 'electronic')
# (1927, None)
# (8364, 'rock')
# (1639, 'rock')
# (7248, 'rock')
# (5039, 'rock')
# (5039, 'experimental')
# (2454, 'rock')
# (6725, 'rock')
# (6617, 'rock')
# (6617, 'experimental')
# (3183, 'rock')
# (5041, 'rock')
# (5041, 'experimental')
# (8718, 'electronic')
# (4718, 'electronic')
# (5383, 'rock')
# (5357, 'rock')
# (891, 'electronic')
# (725, 'pop/r&b')
# (4140, None)
# (2659, 'rock')
# (722, 'pop/r&b')
# (4048, 'rock')
# (7618, 'rock')
# (7618, 'experimental')
# (6377, None)
# (6379, 'rock')
# (5016, 'rock')
# (8060, None)
# (8324, 'electronic')
# (8322, 'electronic')
# (8447, 'rock')
# (3841, 'rock')
# (3431, 'rock')
# (3431, 'metal')
# (7641, 'rock')
# (3888, 'rock')
# (5028, 'pop/r&b')
# (7997, 'rock')
# (4794, 'rock')
# (4794, 'experimental')
# (5529, 'rock')
# (8705, 'electronic')
# (3224, 'pop/r&b')
# (3224, 'folk/country')
# (2251, 'rock')
# (2251, 'experimental')
# (246, 'folk/country')
# (7068, 'rock')
# (5982, None)
# (6621, None)
# (1929, None)
# (5301, 'electronic')
# (363, 'electronic')
# (743, 'pop/r&b')
# (5524, 'rock')
# (5524, 'experimental')
# (301, 'rock')
# (301, 'experimental')
# (301, 'electronic')
# (1412, 'electronic')
# (5298, 'electronic')
# (2667, 'rock')
# (2667, 'electronic')
# (8224, 'electronic')
# (559, 'rock')
# (559, 'electronic')
# (6332, 'electronic')
# (951, None)
# (7873, None)
# (4416, 'electronic')
# (8080, 'electronic')
# (8372, 'rock')
# (8396, None)
# (6634, 'rock')
# (7920, 'electronic')
# (1509, 'jazz')
# (1509, 'experimental')
# (3809, 'rock')
# (3809, 'electronic')
# (6709, 'rock')
# (999, 'rock')
# (4315, 'rock')
# (4315, 'metal')
# (4315, 'experimental')
# (6213, 'rock')
# (3825, 'rock')
# (3825, 'electronic')
# (5344, 'electronic')
# (8428, 'global')
# (1415, 'electronic')
# (7151, 'rock')
# (7507, 'rock')
# (7507, 'electronic')
# (540, 'electronic')
# (7978, 'rock')
# (8116, 'rock')
# (8116, 'metal')
# (8116, 'experimental')
# (6971, 'rock')
# (6971, 'electronic')
# (2403, 'rock')
# (4618, 'rock')
# (4618, 'electronic')
# (7119, 'jazz')
# (7119, 'experimental')
# (1686, 'rock')
# (1686, 'experimental')
# (645, 'rock')
# (2847, 'rock')
# (8562, 'rock')
# (3240, 'rock')
# (5965, 'rock')
# (3830, 'jazz')
# (3830, 'pop/r&b')
# (3830, 'electronic')
# (5970, 'rock')
# (5970, 'experimental')
# (2954, 'rock')
# (1319, 'rock')
# (4795, 'rock')
# (4795, 'experimental')
# (5090, 'rock')
# (6333, 'electronic')
# (7973, 'jazz')
# (7973, 'electronic')
# (2985, 'jazz')
# (2985, 'electronic')
# (5064, 'rock')
# (2831, 'rock')
# (8005, 'jazz')
# (8005, 'pop/r&b')
# (8005, 'electronic')
# (6754, 'rock')
# (8349, 'electronic')
# (3249, 'electronic')
# (5794, 'jazz')
# (5794, 'electronic')
# (678, 'rock')
# (3161, 'rock')
# (2265, 'rock')
# (3437, 'metal')
# (4319, 'rock')
# (3438, 'metal')
# (7682, 'rock')
# (7682, 'global')
# (7682, 'experimental')
# (7682, 'electronic')
# (5386, 'rock')
# (5369, 'rock')
# (8732, 'rock')
# (4628, 'rock')
# (536, 'rock')
# (536, 'experimental')
# (7953, 'rock')
# (8137, 'rock')
# (8137, 'metal')
# (8482, 'electronic')
# (5099, 'rap')
# (5099, 'jazz')
# (5099, 'electronic')
# (3204, 'rock')
# (831, 'rock')
# (7339, None)
# (4850, 'electronic')
# (8598, 'rock')
# (8598, 'experimental')
# (1608, 'electronic')
# (1610, 'electronic')
# (4324, 'rock')
# (7449, 'electronic')
# (1514, 'rock')
# (1514, 'experimental')
# (1514, 'electronic')
# (8677, 'rock')
# (7051, 'rock')
# (7051, 'experimental')
# (6435, 'rock')
# (1014, 'rock')
# (7460, 'rock')
# (2965, 'pop/r&b')
# (7981, None)
# (8835, 'rock')
# (8835, 'electronic')
# (6138, 'experimental')
# (6138, 'electronic')
# (1242, 'rock')
# (1023, 'rock')
# (1023, 'metal')
# (287, 'pop/r&b')
# (287, 'electronic')
# (3741, 'folk/country')
# (6455, 'electronic')
# (361, 'electronic')
# (6372, 'electronic')
# (1535, 'jazz')
# (1535, 'electronic')
# (1341, 'electronic')
# (5376, 'rock')
# (2413, 'rock')
# (2413, 'metal')
# (2413, 'experimental')
# (3723, None)

# %% [markdown]
# ## 1. Cursory Data Analysis:
# a) Compute the number of albums belonging to each genre. You should notice that some albums have multiple genres listed (e.g. Folk/Country,Pop/R&B,Rock) separated by commas. Consider albums with multiple genres as belonging to each of those genres (i.e. an album with Rap,Rock as it’s genres will be counted as one Rap album and one Rock album).
#
# b) Compute the number of albums released each year.
#
# c) Compute the ten artists with the highest number of albums reviewed in the data set.
#
# d) Compute the mean, median, standard deviation, minimum, and maximum album scores.
#
# e) Compute the average score by each review author and return the result in a dataframe sort in descending order.
#
# f) Compute the average album score per artist and return the result in a dataframe with an additional column for the number of albums they’ve had reviewed.
#     i) Return the artists with the top 10 highest average scores
#     ii) Return the artists with the top 10 lowest average scores

# %%
from collections import Counter
import pandas as pd

# %%
'''
a). using Counter to collect the total number of albums belonging to each genre
'''
con = sqlite3.connect("database.sqlite")

cur = con.cursor()

mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT * FROM genres;'):
    mydata.append(row)

# Be sure to close the connection
con.close()

albumsType = [str(x[1]).split('/') for x in mydata]
flattenType = sum(albumsType, [])
albumsFreq = Counter(flattenType)
albumsFreq
# Out:
# Counter({'electronic': 3874,
#          'metal': 860,
#          'rock': 9436,
#          'None': 2367,
#          'rap': 1559,
#          'experimental': 1815,
#          'pop': 1432,
#          'r&b': 1432,
#          'folk': 685,
#          'country': 685,
#          'jazz': 435,
#          'global': 217})

# %%
'''
b). using Counter to Compute the number of albums released each year.
'''
con = sqlite3.connect("database.sqlite")

cur = con.cursor()

mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT * FROM years;'):
    mydata.append(row)

# Be sure to close the connection
con.close()


yearData = [x[1] for x in mydata]
yearData
Counter(yearData)
# Out:
# Counter({1998: 23,
#          2016: 1205,
#          2017: 1,
#          1996: 33,
#          1966: 8,
#          1991: 18,
#          1968: 16,
#          2006: 1182,
#          1993: 19,
#          1988: 16,
#          1962: 3,
#          1984: 11,
#          2003: 1030,
#          1976: 10,
#          1994: 26,
#          1979: 25,
#          1971: 27,
#          1975: 13,
#          1980: 25,
#          1974: 11,
#          1969: 14,
#          1978: 11,
#          1989: 14,
#          1997: 24,
#          1970: 18,
#          2002: 966,
#          1995: 19,
#          1982: 17,
#          2000: 220,
#          1973: 13,
#          1990: 21,
#          1999: 116,
#          1992: 25,
#          1986: 7,
#          1972: 15,
#          1964: 5,
#          1977: 25,
#          1987: 12,
#          2011: 1140,
#          1985: 19,
#          1965: 7,
#          1983: 16,
#          2009: 1149,
#          1981: 25,
#          1960: 3,
#          2015: 1153,
#          2010: 1139,
#          2012: 1179,
#          2014: 1134,
#          2013: 1200,
#          2004: 1046,
#          2008: 1177,
#          2005: 1216,
#          2001: 579,
#          2007: 1265,
#          1967: 7,
#          1963: 3,
#          1959: 1,
#          None: 406})

# %%
'''
c) Compute the ten artists with the highest number of albums reviewed in the data set.
'''
con = sqlite3.connect("database.sqlite")

cur = con.cursor()

mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT * FROM artists;'):
    mydata.append(row)

# Be sure to close the connection
con.close()

artistsData = [x[1] for x in mydata]
Counter(artistsData).most_common(10)
# Out:
# [('various artists', 688),
#  ('neil young', 23),
#  ('guided by voices', 23),
#  ('bonnie prince billy', 22),
#  ('david bowie', 21),
#  ('the beatles', 21),
#  ('gucci mane', 20),
#  ('of montreal', 20),
#  ('mogwai', 20),
#  ('robert pollard', 19)]

# %%
'''
d) Compute the mean, median, standard deviation, minimum, and maximum album scores.
I assume the scores are stored in "reviews" table.
from the below example, it seems the 9.3 is the score field.

[(22703,
  'mezzanine',
  'massive attack',
  'http://pitchfork.com/reviews/albums/22703-mezzanine/',
  9.3,
  0,
  'nate patrin',
  'contributor',
  '2017-01-08',
  6,
  8,
  1,
  2017),
'''
con = sqlite3.connect("database.sqlite")

cur = con.cursor()

mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT * FROM reviews;'):
    mydata.append(row)

# Be sure to close the connection
con.close()

#to use the mean, median, etc from pandas
df = pd.DataFrame([x[4] for x in mydata])

#mean
print('mean :', df[0].mean())

#median
print('median :', df[0].median())

#standard deviation
print('standard deviation :', df[0].std())

#minimum
print('minimum :', df[0].min())

#maximum
print('maximum :', df[0].max())
# Out:
# mean : 7.00577937258735
# median : 7.2
# standard deviation : 1.2936745021540692
# minimum : 0.0
# maximum : 10.0

# %%
'''
e) Compute the average score by each review author and return the result in a dataframe sort in descending order.
'''
con = sqlite3.connect("database.sqlite")

cur = con.cursor()
mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT author, avg(score) FROM reviews GROUP BY author ORDER BY avg(score) DESC '
                      ):
    mydata.append(row)

# Be sure to close the connection
con.close()

df = pd.DataFrame(mydata)
df = df.rename(columns = {0:'author', 1:'average score'})
df
# Out:
#                                 author  average score
# 0                        nelson george      10.000000
# 1                       maura johnston      10.000000
# 2                      carvell wallace       9.833333
# 3                       dorian lynskey       9.500000
# 4    rollie pemberton & nick sylvester       9.400000
# ..                                 ...            ...
# 427                stephen  m. deusner       3.800000
# 428                    bob o. mcmillan       3.500000
# 429                      dr. andy beta       3.300000
# 430      brad haywood & ryan schreiber       3.100000
# 431      chris dahlen & ryan schreiber       1.700000
#
# [432 rows x 2 columns]

# %%
'''
f) Compute the average album score per artist and return the result in a dataframe with an additional 
column for the number of albums they’ve had reviewed. 
i) Return the artists with the top 10 highest average scores 
ii) Return the artists with the top 10 lowest average scores

not sure what the "with an additional column" asking for? combine both i) and ii) in one column?
I would assume maybe return a data frame with the following column names:
   1           2                          3                                   4
artist, average score, artist with 10 highest average score, artist with 10 lowest average score,

'''
con = sqlite3.connect("database.sqlite")

#1&2
cur = con.cursor()

mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT artist, avg(score) FROM reviews GROUP BY artist ORDER BY avg(score) DESC;'):
    mydata.append(row)

#3
top10 = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT artist FROM reviews GROUP BY artist ORDER BY avg(score) DESC LIMIT 10;'):
    top10.append(row)

#4
bot10 = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT artist FROM reviews GROUP BY artist ORDER BY avg(score) ASC LIMIT 10;'):
    bot10.append(row)

# Be sure to close the connection
con.close()

df = pd.concat([pd.DataFrame(mydata).rename(columns = {0:'artist', 1:'average score'}), 
                pd.DataFrame(top10).rename(columns = {0:'artist with 10 highest average score'}),
                pd.DataFrame(bot10).rename(columns = {0:'artist with 10 highest average score'})], axis = 1)
df
# Out:
#                             artist  average score  \
# 0                  the stone roses           10.0
# 1                       television           10.0
# 2                        talk talk           10.0
# 3                    stevie wonder           10.0
# 4                            slint           10.0
# ...                            ...            ...
# 8710                 liars academy            0.6
# 8711                          shat            0.2
# 8712  dan le sac vs. scroobius pip            0.2
# 8713                    push kings            0.1
# 8714               travis morrison            0.0
#
#      artist with 10 highest average score artist with 10 highest average score
# 0                         the stone roses                      travis morrison
# 1                              television                           push kings
# 2                               talk talk         dan le sac vs. scroobius pip
# 3                           stevie wonder                                 shat
# 4                                   slint                        liars academy
# ...                                   ...                                  ...
# 8710                                  NaN                                  NaN
# 8711                                  NaN                                  NaN
# 8712                                  NaN                                  NaN
# 8713                                  NaN                                  NaN
# 8714                                  NaN                                  NaN
#
# [8715 rows x 4 columns]

# %% [markdown]
# ## 2) SQL:
#
# Merge the database tables into a dataframe containing all of the relevant metadata.

# %%
#try to merge all table into a dataframe
con = sqlite3.connect("database.sqlite")

cur = con.cursor()
mydata = []
# available tables: artists, content, genres, labels, reviews, years
for row in cur.execute('SELECT r.reviewid, r.title, r.artist, r.url, r.score, r.best_new_music, r.author, r.author_type, r.pub_date, r.pub_weekday, c.content, g.genre, l.label, y.year FROM reviews AS r JOIN content AS c ON r.reviewid = c.reviewid JOIN genres AS g ON c.reviewid = g.reviewid JOIN labels AS l ON g.reviewid = l.reviewid JOIN years AS y ON g.reviewid = y.reviewid '
                      ):
    mydata.append(row)

# Be sure to close the connection
con.close()

df = pd.DataFrame(mydata).rename(columns = {0:'reviewid', 1:'title', 2:'artist', 
                             3:'url', 4:'score', 5:'best_new_music', 
                             6:'author', 7:'author_type', 8:'pub_date', 
                             9:'pub_weekday', 10:'content', 11:'genre', 12:'label', 13:'year'})
df
# Out:
#        reviewid                        title            artist  \
# 0         22703                    mezzanine    massive attack
# 1         22721                 prelapsarian          krallice
# 2         22659         all of them naturals      uranium club
# 3         22659         all of them naturals      uranium club
# 4         22661                  first songs  kleenex, liliput
# ...         ...                          ...               ...
# 26013      5376                  out of tune          mojave 3
# 26014      2413  singles breaking up, vol. 1     don caballero
# 26015      2413  singles breaking up, vol. 1     don caballero
# 26016      2413  singles breaking up, vol. 1     don caballero
# 26017      3723    left for dead in malaysia    neil hamburger
#
#                                                      url  score  \
# 0      http://pitchfork.com/reviews/albums/22703-mezz...    9.3
# 1      http://pitchfork.com/reviews/albums/22721-prel...    7.9
# 2      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 3      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 4      http://pitchfork.com/reviews/albums/22661-firs...    9.0
# ...                                                  ...    ...
# 26013  http://pitchfork.com/reviews/albums/5376-out-o...    6.3
# 26014  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26015  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26016  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26017  http://pitchfork.com/reviews/albums/3723-left-...    6.5
#
#        best_new_music           author               author_type    pub_date  \
# 0                   0      nate patrin               contributor  2017-01-08
# 1                   0         zoe camp               contributor  2017-01-07
# 2                   0   david glickman               contributor  2017-01-07
# 3                   0   david glickman               contributor  2017-01-07
# 4                   1       jenn pelly  associate reviews editor  2017-01-06
# ...               ...              ...                       ...         ...
# 26013               0   jason josephes               contributor  1999-01-12
# 26014               0  james p. wisdom                      None  1999-01-12
# 26015               0  james p. wisdom                      None  1999-01-12
# 26016               0  james p. wisdom                      None  1999-01-12
# 26017               0   jason josephes               contributor  1999-01-05
#
#        pub_weekday                                            content  \
# 0                6  “Trip-hop” eventually became a ’90s punchline,...
# 1                5  Eight years, five albums, and two EPs in, the ...
# 2                5  Minneapolis’ Uranium Club seem to revel in bei...
# 3                5  Minneapolis’ Uranium Club seem to revel in bei...
# 4                4  Kleenex began with a crash. It transpired one ...
# ...            ...                                                ...
# 26013            1  Out of Tune is a Steve Martin album.  Yes, I'l...
# 26014            1  Well, kids, I just went back and re-read my re...
# 26015            1  Well, kids, I just went back and re-read my re...
# 26016            1  Well, kids, I just went back and re-read my re...
# 26017            1  Neil Hamburger's third comedy release is a des...
#
#               genre               label    year
# 0        electronic              virgin  1998.0
# 1             metal           hathenter  2016.0
# 2              rock  fashionable idiots  2016.0
# 3              rock        static shock  2016.0
# 4              rock     kill rock stars  2016.0
# ...             ...                 ...     ...
# 26013          rock                 4ad     NaN
# 26014  experimental        touch and go  1999.0
# 26015         metal        touch and go  1999.0
# 26016          rock        touch and go  1999.0
# 26017          None           drag city     NaN
#
# [26018 rows x 14 columns]

# %% [markdown]
# ## 3) Dataframe Manipulation (Using the Dataframe from part 2) create new DataFrames based on the stipulations below):
#
# a) Create a new DataFrame excluding all artists with names that start with the letter “M” (either upper or lowercase).
#
# b) Create a new DataFrame excluding albums with a score less than 4.0.
#
# c) Create a new DataFrame excluding albums from the label Columbia
#
# d) Create a new DataFrame excluding albums that belong to the metal genre.
#
# e) Create a new DataFrame excluding albums where that artist’s name contains an even number of characters (including whitespace as characters)
#
# f) Combine these DataFrames into one where each album meets the conditions required for each.

# %%
'''
a)Create a new DataFrame excluding all artists with names that start with the letter “M” (either upper or lowercase).
'''
df[[not str(x).lower().startswith('m') for x in df['artist']]]
# Out:
#        reviewid                        title            artist  \
# 1         22721                 prelapsarian          krallice
# 2         22659         all of them naturals      uranium club
# 3         22659         all of them naturals      uranium club
# 4         22661                  first songs  kleenex, liliput
# 5         22661                  first songs  kleenex, liliput
# ...         ...                          ...               ...
# 26012      1341                         1999           cassius
# 26014      2413  singles breaking up, vol. 1     don caballero
# 26015      2413  singles breaking up, vol. 1     don caballero
# 26016      2413  singles breaking up, vol. 1     don caballero
# 26017      3723    left for dead in malaysia    neil hamburger
#
#                                                      url  score  \
# 1      http://pitchfork.com/reviews/albums/22721-prel...    7.9
# 2      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 3      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 4      http://pitchfork.com/reviews/albums/22661-firs...    9.0
# 5      http://pitchfork.com/reviews/albums/22661-firs...    9.0
# ...                                                  ...    ...
# 26012     http://pitchfork.com/reviews/albums/1341-1999/    4.8
# 26014  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26015  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26016  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 26017  http://pitchfork.com/reviews/albums/3723-left-...    6.5
#
#        best_new_music           author               author_type    pub_date  \
# 1                   0         zoe camp               contributor  2017-01-07
# 2                   0   david glickman               contributor  2017-01-07
# 3                   0   david glickman               contributor  2017-01-07
# 4                   1       jenn pelly  associate reviews editor  2017-01-06
# 5                   1       jenn pelly  associate reviews editor  2017-01-06
# ...               ...              ...                       ...         ...
# 26012               0  james p. wisdom                      None  1999-01-26
# 26014               0  james p. wisdom                      None  1999-01-12
# 26015               0  james p. wisdom                      None  1999-01-12
# 26016               0  james p. wisdom                      None  1999-01-12
# 26017               0   jason josephes               contributor  1999-01-05
#
#        pub_weekday                                            content  \
# 1                5  Eight years, five albums, and two EPs in, the ...
# 2                5  Minneapolis’ Uranium Club seem to revel in bei...
# 3                5  Minneapolis’ Uranium Club seem to revel in bei...
# 4                4  Kleenex began with a crash. It transpired one ...
# 5                4  Kleenex began with a crash. It transpired one ...
# ...            ...                                                ...
# 26012            1  Well, it's been two weeks now, and I guess it'...
# 26014            1  Well, kids, I just went back and re-read my re...
# 26015            1  Well, kids, I just went back and re-read my re...
# 26016            1  Well, kids, I just went back and re-read my re...
# 26017            1  Neil Hamburger's third comedy release is a des...
#
#               genre               label    year
# 1             metal           hathenter  2016.0
# 2              rock  fashionable idiots  2016.0
# 3              rock        static shock  2016.0
# 4              rock     kill rock stars  2016.0
# 5              rock         mississippi  2016.0
# ...             ...                 ...     ...
# 26012    electronic         astralwerks     NaN
# 26014  experimental        touch and go  1999.0
# 26015         metal        touch and go  1999.0
# 26016          rock        touch and go  1999.0
# 26017          None           drag city     NaN
#
# [24064 rows x 14 columns]

# %% [markdown]
# ## 4) Feature Engineering:
#
# a) Construct a Pandas DataFrame (see problem 2) containing all album reviews and metadata. Remove any rows that have null values in any column.
#
# b) Add a column to the dataframe for each genre. The entry in this column should be a 1 if the album/row in question belongs to that genre and 0 otherwise. Remember that albums can belong to multiple genres.
#
# c) Add an additional two columns with categorical variables for 1) the author of the review and 2) the role of the author.
#
# d) Create a column for the number of words in the review.
#
# e) Create a column containing the sentiment score of the review. Treat the review as a single string and take the TextBlob polarity score (https://textblob.readthedocs.io/en/dev/quickstart.html).

# %%
'''
a)Construct a Pandas DataFrame (see problem 2) containing all album reviews and metadata. 
Remove any rows that have null values in any column.
'''
df = df.dropna()

'''
b) Add a column to the dataframe for each genre. 
The entry in this column should be a 1 if the album/row in question belongs to that genre and 0 otherwise. 
Remember that albums can belong to multiple genres.

From question 1 we know the genre has the following kinds:
'electronic','metal','rock','rap','experimental','pop','r&b','folk','country','jazz','global'
'''
genreList = ['electronic','metal','rock','rap','experimental','pop',
             'r&b','folk','country','jazz','global']

#insert each genre type with value 0
#then change value to 1 if condition met
for i in genreList:
    #     index = ['electronic' in x for x in df['genre']]
    #     df.loc[index, 'electronic'] = 1
    df[i] = 0
    index = [i in x for x in df['genre']]
    df.loc[index, i] = 1
    
# print('check column names :', df.columns)

# print('check if jazz has value change to 1 if condition met :', df['jazz'].value_counts())

# test = df[df['folk'] == 1]
# print('check one example to see if it has the case of both fold and country set to 1 :', 
#       test[test['country'] == 1].head(1))

'''
c) Add an additional two columns with categorical variables for 
1) the author of the review and 
2) the role of the author.

create additional two columns with categroical variables? we already have "author" and "author_type".
They are categorical already. Not sure what this question is asking.
'''

'''
d) Create a column for the number of words in the review.
number of words in the review? the reviews table has multiple columns. 
Which column do we mean here or all column together from reviews table?

I could only assume the review here means the "content" variable from the dataframe.
'''
df['review words'] = [len(re.split(r'\W+', x)) for x in df['content']]


'''
e) Create a column containing the sentiment score of the review. Treat the review as a single string and 
take the TextBlob polarity score (https://textblob.readthedocs.io/en/dev/quickstart.html).
'''

df['sentiment_score'] = [TextBlob(x).sentiment.polarity for x in df['content']]
df
# Out:
# <ipython-input-401-6a893f338ea1>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = 0
# /Users/johnnyliu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-401-6a893f338ea1>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review words'] = [len(re.split(r'\W+', x)) for x in df['content']]
# <ipython-input-401-6a893f338ea1>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment_score'] = [TextBlob(x).sentiment.polarity for x in df['content']]
#        reviewid                  title            artist  \
# 0         22703              mezzanine    massive attack
# 1         22721           prelapsarian          krallice
# 2         22659   all of them naturals      uranium club
# 3         22659   all of them naturals      uranium club
# 4         22661            first songs  kleenex, liliput
# ...         ...                    ...               ...
# 25981      7449  budakhan mindphone ep      squarepusher
# 25982      7449  budakhan mindphone ep      squarepusher
# 25992      1014  keep it like a secret    built to spill
# 26007       361           peel session          autechre
# 26008       361           peel session          autechre
#
#                                                      url  score  \
# 0      http://pitchfork.com/reviews/albums/22703-mezz...    9.3
# 1      http://pitchfork.com/reviews/albums/22721-prel...    7.9
# 2      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 3      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 4      http://pitchfork.com/reviews/albums/22661-firs...    9.0
# ...                                                  ...    ...
# 25981  http://pitchfork.com/reviews/albums/7449-budak...    7.5
# 25982  http://pitchfork.com/reviews/albums/7449-budak...    7.5
# 25992  http://pitchfork.com/reviews/albums/1014-keep-...    9.3
# 26007  http://pitchfork.com/reviews/albums/361-peel-s...    7.7
# 26008  http://pitchfork.com/reviews/albums/361-peel-s...    7.7
#
#        best_new_music          author               author_type    pub_date  \
# 0                   0     nate patrin               contributor  2017-01-08
# 1                   0        zoe camp               contributor  2017-01-07
# 2                   0  david glickman               contributor  2017-01-07
# 3                   0  david glickman               contributor  2017-01-07
# 4                   1      jenn pelly  associate reviews editor  2017-01-06
# ...               ...             ...                       ...         ...
# 25981               0  ryan schreiber           editor-in-chief  1999-03-02
# 25982               0  ryan schreiber           editor-in-chief  1999-03-02
# 25992               0  jason josephes               contributor  1999-02-23
# 26007               0  ryan schreiber           editor-in-chief  1999-02-09
# 26008               0  ryan schreiber           editor-in-chief  1999-02-09
#
#        pub_weekday  ... rap experimental pop  r&b  folk  country  jazz  \
# 0                6  ...   0            0   0    0     0        0     0
# 1                5  ...   0            0   0    0     0        0     0
# 2                5  ...   0            0   0    0     0        0     0
# 3                5  ...   0            0   0    0     0        0     0
# 4                4  ...   0            0   0    0     0        0     0
# ...            ...  ...  ..          ...  ..  ...   ...      ...   ...
# 25981            1  ...   0            0   0    0     0        0     0
# 25982            1  ...   0            0   0    0     0        0     0
# 25992            1  ...   0            0   0    0     0        0     0
# 26007            1  ...   0            0   0    0     0        0     0
# 26008            1  ...   0            0   0    0     0        0     0
#
#        global  review words  sentiment_score
# 0           0          1593         0.097281
# 1           0           449         0.041640
# 2           0           624         0.123304
# 3           0           624         0.123304
# 4           0          1337         0.161576
# ...       ...           ...              ...
# 25981       0           236         0.126768
# 25982       0           236         0.126768
# 25992       0           911         0.135315
# 26007       0           465         0.242104
# 26008       0           465         0.242104
#
# [17904 rows x 27 columns]

# %% [markdown]
# ## 5) Logistic Regression:
#
# You will now use the features you constructed in the previous exercise to complete a binary logistic regression task accounting for whether an album reviews Pitchfork’s designation of “Best New Music.” This is represented by the binary “bnm” variable in the dataset.
#
# a) Scale all non-categorical variables as needed.
#
# b) Perform your logistic regression model using the statsmodel library (https://www.pythonfordatascience.org/logistic-regression-python/ ). Treat the best new music variable as your dependent variable and use the release year, word count, sentiment, all genre binary variables, author, and author role as your independent variables.
#
# c) Calculate the odds ratios for your independent variables
#
# d) What features are most/least predictive of a best new music designation and why do you think that is?
#
# e) If you were to engineer an additional feature for the regression, what would it be? Describe how you would approach constructing that feature.

# %%
dir(model)
dir(smf)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'gee',
#  'glm',
#  'glmgam',
#  'gls',
#  'glsar',
#  'logit',
#  'mixedlm',
#  'mnlogit',
#  'negativebinomial',
#  'nominal_gee',
#  'ols',
#  'ordinal_gee',
#  'phreg',
#  'poisson',
#  'probit',
#  'quantreg',
#  'rlm',
#  'wls']

# %%
# df['best_new_music']
'''
a) Scale all non-categorical variables as needed.

For this question, I will scale any non-categorical variables if needed.
Also, will check if some numeric categorical variable is under the range with no typo.
'''
# check non-categorical
#check score
df.score.value_counts()#score seems not need to be scaled.

#check review words
sorted(df['review words'].unique())#this review words have range from 1 to thousands. Need to scale this one.
df['normalized_review_words'] = (df['review words'] - df['review words'].mean())/df['review words'].std()


#check categorical
#check pub_weekday
df.pub_weekday.value_counts()#from 0-6 which is fine

#check pub_date
df.pub_date.value_counts()
pd.Series([len(x) for x in df.pub_date]).value_counts()#seems fine, all have the same length. 

#check year
df.year = [int(x) for x in df['year']]
sorted(df.year.unique())#1961 year data is missing. But it should be fine.

#check electronic
df.electronic.value_counts()#no problem as expected

df['rnb'] = df['r&b']

df=df.reset_index(drop=True)

'''
b) Perform your logistic regression model using the statsmodel library 
(https://www.pythonfordatascience.org/logistic-regression-python/ ). 
Treat the best new music variable as your dependent variable and use the 
release year, word count, sentiment, all genre binary variables, author, and author role as 
your independent variables.

genre list:'electronic','metal','rock','rap','experimental','pop',
             'r&b','folk','country','jazz','global'

Before run the model, I actually want to check how balance the data is. 

let's them check correlation among variables especially music type
'''
corr = df[['electronic','metal','rock','rap','experimental','pop',
             'r&b','folk','country','jazz','global']].corr()
# corr = df.corr()
corr
# Out:
#               electronic     metal      rock       rap  experimental  \
# electronic      1.000000 -0.094636 -0.445967 -0.146329     -0.152262
# metal          -0.094636  1.000000 -0.180366 -0.059181     -0.061581
# rock           -0.445967 -0.180366  1.000000 -0.278888     -0.290197
# rap            -0.146329 -0.059181 -0.278888  1.000000     -0.095218
# experimental   -0.152262 -0.061581 -0.290197 -0.095218      1.000000
# pop            -0.136137 -0.055059 -0.259463 -0.085134     -0.088586
# r&b            -0.136137 -0.055059 -0.259463 -0.085134     -0.088586
# folk           -0.090926 -0.036774 -0.173295 -0.056861     -0.059167
# country        -0.090926 -0.036774 -0.173295 -0.056861     -0.059167
# jazz           -0.068205 -0.027585 -0.129991 -0.042652     -0.044382
# global         -0.055666 -0.022513 -0.106094 -0.034811     -0.036223
#
#                    pop       r&b      folk   country      jazz    global
# electronic   -0.136137 -0.136137 -0.090926 -0.090926 -0.068205 -0.055666
# metal        -0.055059 -0.055059 -0.036774 -0.036774 -0.027585 -0.022513
# rock         -0.259463 -0.259463 -0.173295 -0.173295 -0.129991 -0.106094
# rap          -0.085134 -0.085134 -0.056861 -0.056861 -0.042652 -0.034811
# experimental -0.088586 -0.088586 -0.059167 -0.059167 -0.044382 -0.036223
# pop           1.000000  1.000000 -0.052901 -0.052901 -0.039681 -0.032387
# r&b           1.000000  1.000000 -0.052901 -0.052901 -0.039681 -0.032387
# folk         -0.052901 -0.052901  1.000000  1.000000 -0.026503 -0.021631
# country      -0.052901 -0.052901  1.000000  1.000000 -0.026503 -0.021631
# jazz         -0.039681 -0.039681 -0.026503 -0.026503  1.000000 -0.016226
# global       -0.032387 -0.032387 -0.021631 -0.021631 -0.016226  1.000000

# %%
'''
From the above table:
1. we can see pop and r&b are perfect correlated with correlation of 1.0. So we would only need one of them.
2. folk and country has correlation of 1.0. We only need one of them.
3. rock and electronic have moderate correlation.
4. The others have low correlations among them.


Then, I would like to do a stepwise forward selection to check which variable are significant to our outcome.
'''
#1) run single varaible year
model = smf.logit("best_new_music~ year", data = df).fit()

model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.272732
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17902
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:                0.001333
# Time:                        16:21:47   Log-Likelihood:                -4883.0
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                 0.0003050
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     25.5467      7.490      3.411      0.001      10.867      40.226
# year          -0.0140      0.004     -3.741      0.000      -0.021      -0.007
# ==============================================================================
# """

# %%
'''
the result from above year only model seems interesting. The p-value is 0 < 0.05. It indicate that for every one unit increase
in year, the best new music decrease with log odds by 0.0140. Somehow we can tell people are setting higher 
expectation for best new music year by year.
'''

# %%
#2). run single varaible normalized_review_words

model = smf.logit("best_new_music~ normalized_review_words", data = df).fit()

model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.228672
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17902
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:                  0.1627
# Time:                        16:24:21   Log-Likelihood:                -4094.1
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -2.8264      0.035    -81.526      0.000      -2.894      -2.758
# normalized_review_words     0.9149      0.025     36.372      0.000       0.866       0.964
# ===========================================================================================
# """

# %%
'''
The p-value is 0 < 0.05. It indicate that for every one unit increase
in normalized_review_words, the best new music increase with log odds by 0.9149.
'''
# Out:
# 0    17555
# 1      349
# Name: jazz, dtype: int64

# %%
#3). run single varaible sentiment_score

model = smf.logit("best_new_music~ sentiment_score", data = df).fit()

model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.272826
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17902
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:               0.0009884
# Time:                        16:25:43   Log-Likelihood:                -4884.7
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                  0.001878
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -2.6635      0.068    -39.129      0.000      -2.797      -2.530
# sentiment_score     1.5382      0.496      3.102      0.002       0.566       2.510
# ===================================================================================
# """

# %%
'''
The p-value is 0 < 0.05. It indicate that for every one unit increase
in sentiment_score, the best new music increase with log odds by 1.5382.
'''

# %%
#4). run single varaible C(author_type)

model = smf.logit("best_new_music~ C(author_type)", data = df).fit()

model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265241
#          Iterations: 35
# /Users/johnnyliu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17889
# Method:                           MLE   Df Model:                           14
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:                 0.02876
# Time:                        16:26:47   Log-Likelihood:                -4748.9
# converged:                      False   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                 9.384e-52
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                      -1.7918      0.624     -2.873      0.004      -3.014      -0.570
# C(author_type)[T.associate editor]            -29.9437   1.09e+06  -2.75e-05      1.000   -2.14e+06    2.14e+06
# C(author_type)[T.associate features editor]    -0.1542      0.980     -0.157      0.875      -2.075       1.767
# C(author_type)[T.associate reviews editor]      1.3535      0.686      1.972      0.049       0.008       2.699
# C(author_type)[T.associate staff writer]       -1.3083      0.773     -1.692      0.091      -2.824       0.207
# C(author_type)[T.contributing editor]          -0.4691      0.663     -0.708      0.479      -1.768       0.830
# C(author_type)[T.contributor]                  -0.8528      0.624     -1.366      0.172      -2.077       0.371
# C(author_type)[T.deputy news editor]           -1.1939      0.774     -1.543      0.123      -2.711       0.323
# C(author_type)[T.editor-in-chief]               0.1178      0.698      0.169      0.866      -1.251       1.487
# C(author_type)[T.executive editor]              0.4643      0.631      0.736      0.462      -0.772       1.701
# C(author_type)[T.managing editor]               1.0986      1.374      0.799      0.424      -1.595       3.792
# C(author_type)[T.news director]                 0.6931      1.312      0.528      0.597      -1.879       3.265
# C(author_type)[T.senior editor]                 0.3117      0.632      0.493      0.622      -0.927       1.550
# C(author_type)[T.senior staff writer]          -0.6807      0.642     -1.060      0.289      -1.939       0.577
# C(author_type)[T.tracks coordinator]           -1.0217      0.862     -1.186      0.236      -2.710       0.667
# ===============================================================================================================
# """

# %%
'''
we can tell most of the time, the author type does not correlate to our outcome best_new_music.
Only C(author_type)[T.associate reviews editor] and C(author_type)[T.associate staff writer] have 
significant p-value. But it also not make sense if we have have these two significant but has something like
senior staff writer that has no significant p-value.

Also, from the below spearman corelation, we can tell author_type has very small correlation with best_new_music 
'''

corr, _ = spearmanr(df['best_new_music'], df['author_type'])
corr
# Out:
# 0.08068350886487367

# %%
#5). run single varaible C(author)

'''
if we simply run below regression, it will raise singular matrix problem. 
It is due to we have many different authors. Compare to out data size, the variables are too much.
model = smf.logit("best_new_music~ C(author)", data = df).fit()
model.summary()

df['author'].value_counts() #we have 246 different authors 

Instead of using all the authors, 
maybe we can try making them to three groups: >200: high, 100-200: moderate, 100<: low
'''
myCounter = Counter(df['author'])
high_list = [x for x, y in myCounter.items() if y >200 ]
moderate_list = [x for x, y in myCounter.items() if y >100 and y<=200]
low_list = [x for x, y in myCounter.items() if y <=100]

df['cat_author'] = list(df['author'])
for j in range(len(df['cat_author'])):
    if df['cat_author'][j] in high_list:
        df['cat_author'][j] = 'high'
    elif df['cat_author'][j] in moderate_list:
        df['cat_author'][j] = 'moderate'
    else:
        df['cat_author'][j] = 'low'
        
model = smf.logit("best_new_music~ C(cat_author)", data = df).fit()
model.summary()
# Out:
# <ipython-input-510-56d97e34d148>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cat_author'][j] = 'high'
# <ipython-input-510-56d97e34d148>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cat_author'][j] = 'low'
# <ipython-input-510-56d97e34d148>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cat_author'][j] = 'moderate'
# Optimization terminated successfully.
#          Current function value: 0.273093
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17901
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:               1.035e-05
# Time:                        17:03:45   Log-Likelihood:                -4889.5
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                    0.9507
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -2.4675      0.035    -71.074      0.000      -2.536      -2.399
# C(cat_author)[T.low]         -0.0189      0.072     -0.264      0.792      -0.159       0.121
# C(cat_author)[T.moderate]    -0.0181      0.079     -0.230      0.818      -0.173       0.137
# =============================================================================================
# """

# %%
'''
From the above result, we can conclude even if we further group author to 3 types, 
there is no relationship bettween author and outcome.
'''

# %%
#6). we then run varaibles music type

'''
remember the conclusion from previous
1. we can see pop and r&b are perfect correlated with correlation of 1.0. So we would only need one of them.
2. folk and country has correlation of 1.0. We only need one of them.
3. rock and electronic have moderate correlation.
'''

model = smf.logit("best_new_music~ C(rock)", data = df).fit()
'''
The p-value < 0.05. It indicate the best new music increase with log odds by 0.1654 if we have variable rock.
'''

model = smf.logit("best_new_music~ C(rap)", data = df).fit()
'''
not significant
'''

model = smf.logit("best_new_music~ C(experimental)", data = df).fit()
'''
The p-value < 0.05. It indicate the best new music increase with log odds by 0.2253 if we have variable experimental.
'''

model = smf.logit("best_new_music~ C(pop)", data = df).fit()
'''
The p-value < 0.05. It indicate the best new music increase with log odds by 0.2017 if we have variable pop.
'''

model = smf.logit("best_new_music~ C(folk)", data = df).fit()
'''
The p-value < 0.05. It indicate the best new music decrease with log odds by 0.5399 if we have variable folk.
folk is unfavorable for best_new_music
'''

model = smf.logit("best_new_music~ C(jazz)", data = df).fit()
'''
not significant
'''

model = smf.logit("best_new_music~ C(metal)", data = df).fit()
'''
The p-value < 0.05. It indicate the best new music decrease with log odds by 0.5875 if we have variable metal.
metal is unfavorable for best_new_music
'''

model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.272852
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.273033
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.272931
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.272987
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.272838
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.273085
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.272775
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17902
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:                0.001175
# Time:                        17:17:07   Log-Likelihood:                -4883.8
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                 0.0006994
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -2.4570      0.028    -86.993      0.000      -2.512      -2.402
# C(metal)[T.1]    -0.5875      0.189     -3.109      0.002      -0.958      -0.217
# =================================================================================
# """

# %%
#then let's combine all significant variables step by step and achieve the following:
'''
model = smf.logit("best_new_music~ C(rock) + C(experimental)", data = df).fit()

model = smf.logit("best_new_music~ C(rock) + C(experimental) + C(pop)", data = df).fit()

model = smf.logit("best_new_music~ C(rock) + C(experimental) + C(pop)+ normalized_review_words", data = df).fit()

model = smf.logit("best_new_music~ C(rock) + C(experimental) + C(pop)+ normalized_review_words + sentiment_score", data = df).fit()

some steps are omit here.
'''
#the best model so far and the model converge
model = smf.logit("best_new_music~ C(rock) + C(experimental)+ \
normalized_review_words + sentiment_score + year +C(rnb) + C(electronic)", data = df).fit()

#not going to add the interaction term here due to time limit and also it is usually not easy for interpretation by adding interaction term.
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.226075
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         best_new_music   No. Observations:                17904
# Model:                          Logit   Df Residuals:                    17896
# Method:                           MLE   Df Model:                            7
# Date:                Mon, 04 Oct 2021   Pseudo R-squ.:                  0.1722
# Time:                        17:32:19   Log-Likelihood:                -4047.7
# converged:                       True   LL-Null:                       -4889.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -38.2514      8.004     -4.779      0.000     -53.938     -22.564
# C(rock)[T.1]                0.5222      0.092      5.654      0.000       0.341       0.703
# C(experimental)[T.1]        0.8290      0.124      6.700      0.000       0.586       1.071
# C(rnb)[T.1]                 0.6035      0.133      4.551      0.000       0.344       0.863
# C(electronic)[T.1]          0.6057      0.109      5.561      0.000       0.392       0.819
# normalized_review_words     0.9552      0.026     36.495      0.000       0.904       1.007
# sentiment_score             2.4647      0.588      4.191      0.000       1.312       3.617
# year                        0.0172      0.004      4.331      0.000       0.009       0.025
# ===========================================================================================
# """

# %%
'''
c) Calculate the odds ratios for your independent variables
'''
model_odds = pd.DataFrame(np.exp(model.params), columns= ['OR'])
model_odds['z-value']= model.pvalues
model_odds[['2.5%', '97.5%']] = np.exp(model.conf_int())

model_odds
# Out:
#                                    OR        z-value          2.5%  \
# Intercept                2.441451e-17   1.759677e-06  3.757651e-24
# C(rock)[T.1]             1.685794e+00   1.568960e-08  1.406631e+00
# C(experimental)[T.1]     2.290978e+00   2.087065e-11  1.797629e+00
# C(rnb)[T.1]              1.828494e+00   5.350701e-06  1.409962e+00
# C(electronic)[T.1]       1.832589e+00   2.684649e-08  1.480287e+00
# normalized_review_words  2.599221e+00  1.330547e-291  2.469245e+00
# sentiment_score          1.176016e+01   2.775265e-05  3.714012e+00
# year                     1.017385e+00   1.484223e-05  1.009481e+00
#
#                                 97.5%
# Intercept                1.586279e-10
# C(rock)[T.1]             2.020359e+00
# C(experimental)[T.1]     2.919723e+00
# C(rnb)[T.1]              2.371264e+00
# C(electronic)[T.1]       2.268738e+00
# normalized_review_words  2.736040e+00
# sentiment_score          3.723776e+01
# year                     1.025352e+00

# %%
'''
d) What features are most/least predictive of a best new music designation and why do you think that is?

1).We have remove some features by the stepwise forward selection process and correlation analysis. Details have 
been talked during above process. 
I am not goning to repeat here why some features are not good and have been removed.

2).From the above best model, we have all significant features left. 
Among these features, we can see sentiment_score is a very strong feature which has 1.17e+01 OR.
It does make sense cause how the best music selected should be really based on its content.

In terms of review words, people is more likely to write longer review for what they loved.

Also, some music type might be more favorable like rock, r&b, etc compare to jazz which is likely more minority.
'''

# %%
'''
e) If you were to engineer an additional feature for the regression, what would it be? 
Describe how you would approach constructing that feature.

I would probably consider month data. Maybe during some month close to music season. 
The music that published close to such time might get more attention and are likely to achieve a better review.

Also, I might want to create a feature that capture artist rating. 
In order to get such feature, I could web scrapping artist review, description, etc from source like twitter.

'''

# %% [markdown]
# ## 6) Data Visualization (Optional):
#
# Using the results from your regression and data analysis create a visualization that tells a story about the data. Feel free to take personal liberties with this and be as creative as you like.
